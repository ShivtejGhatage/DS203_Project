# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
 

for song_no in range(1,10):
    # Load the MFCC file
    file_path = './MFCC-files-v2/' + '0' + str(song_no) + '-MFCC.csv'  # Update with your file path
    mfcc_data = pd.read_csv(file_path, header=None)  # Assumaxg the file has no header

    # Calculate the max for each row (axis=1 computes max across columns for each row)
    mfcc_max = mfcc_data.max(axis=1)

    # Convert the result to a DataFrame with 20 rows and 1 column
    mfcc_max_df = pd.DataFrame(mfcc_max)

    # Print the result to verify
    

    scaler = StandardScaler()
    mfcc_max_standardized = scaler.fit_transform(mfcc_max_df)

    # Convert back to DataFrame for saving
    mfcc_standardized_df = pd.DataFrame(mfcc_max_standardized)

    print(mfcc_standardized_df)
    # Optionally, save the result to a new CSV file
    mfcc_standardized_df.to_csv('MFCC_Max/mfcc_output_' + str(song_no) +'.csv', index=False, header=False)

    # mfcc_max_df.to_csv('MFCC_max/mfcc_max_output' + str(song_no) +'.csv', index=False, header=False)



for song_no in range(10,116):
    # Load the MFCC file
    file_path = './MFCC-files-v2/' + str(song_no) + '-MFCC.csv'  # Update with your file path
    mfcc_data = pd.read_csv(file_path, header=None)  # Assumaxg the file has no header

    # Calculate the max for each row (axis=1 computes max across columns for each row)
    mfcc_max = mfcc_data.max(axis=1)

    # Convert the result to a DataFrame with 20 rows and 1 column
    mfcc_max_df = pd.DataFrame(mfcc_max)


    scaler = StandardScaler()
    mfcc_max_standardized = scaler.fit_transform(mfcc_max_df)

    # Convert back to DataFrame for saving
    mfcc_standardized_df = pd.DataFrame(mfcc_max_standardized)


    # Print the result to verify
    print(mfcc_standardized_df)

    # Optionally, save the result to a new CSV file
    mfcc_standardized_df.to_csv('MFCC_Max/mfcc_output_' + str(song_no) +'.csv', index=False, header=False)



    # mfcc_max_df.to_csv('MFCC_max/mfcc_max_output_' + str(song_no) +'.csv', index=False, header=False)
# Out:
#            0
# 0  -1.977742
# 1   3.819235
# 2   0.556739
# 3   0.300154
# 4   0.096496
# 5   0.277409
# 6  -0.092031
# 7   0.141860
# 8  -0.223757
# 9  -0.194242
# 10 -0.410181
# 11 -0.232938
# 12 -0.370520
# 13 -0.339688
# 14 -0.153059
# 15 -0.054895
# 16 -0.258654
# 17 -0.489130
# 18 -0.279570
# 19 -0.115487
#            0
# 0  -2.089918
# 1   3.403410
# 2   0.295340
# 3   1.412766
# 4   0.322911
# 5   0.445265
# 6  -0.026027
# 7  -0.079673
# 8  -0.058492
# 9  -0.287257
# 10 -0.459186
# 11  0.228486
# 12 -0.410513
# 13 -0.357218
# 14 -0.210866
# 15 -0.373617
# 16 -0.620291
# 17 -0.290365
# 18 -0.447838
# 19 -0.396917
#            0
# 0  -0.080042
# 1   3.889905
# 2   0.623825
# 3   1.114315
# 4  -0.233268
# 5   0.400632
# 6  -0.552979
# 7  -0.066919
# 8  -0.053522
# 9  -0.315174
# 10 -0.351766
# 11 -0.206683
# 12 -0.470438
# 13 -0.581466
# 14 -0.144113
# 15 -0.606319
# 16 -0.389509
# 17 -0.802265
# 18 -0.537158
# 19 -0.637058
#            0
# 0  -3.131677
# 1   2.656737
# 2  -0.201761
# 3   1.270559
# 4   0.144633
# 5   0.603021
# 6  -0.268736
# 7   0.655629
# 8   0.119194
# 9   0.081353
# 10  0.112729
# 11 -0.268694
# 12 -0.238292
# 13 -0.311077
# 14 -0.075728
# 15 -0.271812
# 16 -0.053231
# 17 -0.401608
# 18 -0.188710
# 19 -0.232529
#            0
# 0  -2.751365
# 1   3.315209
# 2   0.259324
# 3   0.788445
# 4   0.516450
# 5  -0.083854
# 6   0.251741
# 7  -0.160726
# 8  -0.171590
# 9  -0.202914
# 10 -0.204198
# 11 -0.153240
# 12 -0.198557
# 13 -0.131462
# 14 -0.172227
# 15 -0.222598
# 16 -0.168939
# 17 -0.157629
# 18 -0.192008
# 19 -0.159862
#            0
# 0  -1.742056
# 1   3.433384
# 2   0.038477
# 3   1.766361
# 4  -0.234292
# 5   0.688898
# 6  -0.429344
# 7  -0.211209
# 8  -0.423550
# 9   0.069505
# 10 -0.447500
# 11 -0.429763
# 12 -0.401107
# 13 -0.364020
# 14 -0.160691
# 15 -0.393635
# 16 -0.209714
# 17 -0.355286
# 18  0.082662
# 19 -0.277121
#            0
# 0  -2.730548
# 1   3.379455
# 2   0.197528
# 3   0.809518
# 4   0.212045
# 5  -0.042626
# 6   0.004896
# 7  -0.043243
# 8  -0.107226
# 9   0.095330
# 10 -0.128932
# 11 -0.118756
# 12 -0.313732
# 13 -0.172623
# 14 -0.233195
# 15 -0.216227
# 16 -0.062121
# 17 -0.177643
# 18 -0.210419
# 19 -0.141478
#            0
# 0  -0.678237
# 1   3.807439
# 2   0.365674
# 3   1.478462
# 4  -0.092835
# 5   0.343037
# 6  -0.391750
# 7   0.000266
# 8  -0.280931
# 9   0.159966
# 10 -0.511979
# 11 -0.204201
# 12 -0.495493
# 13 -0.449807
# 14 -0.584530
# 15 -0.606447
# 16 -0.423454
# 17 -0.569490
# 18 -0.425476
# 19 -0.440214
#            0
# 0  -3.012730
# 1   3.181393
# 2   0.368791
# 3   0.300563
# 4   0.626431
# 5  -0.079507
# 6  -0.017631
# 7  -0.051985
# 8  -0.181547
# 9  -0.113994
# 10 -0.089528
# 11 -0.132567
# 12 -0.037416
# 13 -0.087334
# 14 -0.060494
# 15 -0.075169
# 16 -0.044681
# 17 -0.180783
# 18 -0.177466
# 19 -0.134346
#            0
# 0  -2.309911
# 1   3.623408
# 2   0.053923
# 3   0.486695
# 4  -0.119697
# 5   0.205524
# 6   0.257249
# 7  -0.596953
# 8   0.047256
# 9   0.375761
# 10 -0.495473
# 11 -0.220696
# 12 -0.057784
# 13 -0.343032
# 14 -0.401971
# 15 -0.128215
# 16  0.021722
# 17 -0.259138
# 18 -0.034298
# 19 -0.104369
#            0
# 0  -1.741833
# 1   3.347855
# 2  -0.478881
# 3   1.948237
# 4  -0.001632
# 5   0.233667
# 6  -0.348746
# 7  -0.054579
# 8  -0.640005
# 9  -0.433340
# 10 -0.260384
# 11 -0.593518
# 12 -0.526800
# 13 -0.387371
# 14 -0.137419
# 15 -0.010716
# 16 -0.158753
# 17 -0.054907
# 18  0.241054
# 19  0.058071
#            0
# 0  -1.777218
# 1   3.035075
# 2   0.563290
# 3   1.364772
# 4   0.115579
# 5   1.561969
# 6  -0.584157
# 7   0.708770
# 8  -0.467230
# 9  -0.247031
# 10 -0.468805
# 11 -0.299722
# 12 -0.515691
# 13 -0.504292
# 14 -0.431620
# 15 -0.426590
# 16 -0.340162
# 17 -0.501775
# 18 -0.388750
# 19 -0.396413
#            0
# 0  -1.109467
# 1   3.446108
# 2  -0.623487
# 3   2.184316
# 4   0.190148
# 5   0.112515
# 6  -0.556532
# 7  -0.122646
# 8  -0.414481
# 9  -0.488903
# 10 -0.485970
# 11 -0.511973
# 12 -0.337996
# 13 -0.003489
# 14 -0.418140
# 15 -0.152418
# 16 -0.142902
# 17 -0.185017
# 18 -0.113318
# 19 -0.266349
#            0
# 0  -2.213905
# 1   3.174504
# 2   1.058811
# 3   1.541041
# 4  -0.025327
# 5   0.260986
# 6  -0.347710
# 7   0.023925
# 8  -0.568138
# 9  -0.184785
# 10 -0.335727
# 11 -0.240215
# 12  0.003287
# 13 -0.364112
# 14 -0.039747
# 15 -0.130729
# 16 -0.370026
# 17 -0.472696
# 18 -0.390027
# 19 -0.379411
#            0
# 0  -2.352725
# 1   3.404225
# 2   0.144299
# 3   1.141674
# 4  -0.250747
# 5   0.723400
# 6  -0.345719
# 7   0.096038
# 8  -0.291343
# 9  -0.013053
# 10 -0.073354
# 11 -0.464708
# 12 -0.386145
# 13 -0.220808
# 14 -0.064088
# 15 -0.359834
# 16 -0.070182
# 17 -0.390940
# 18 -0.024571
# 19 -0.201420
#            0
# 0  -1.983487
# 1   3.582976
# 2   0.061991
# 3   1.255532
# 4   0.156625
# 5   0.582466
# 6  -0.304272
# 7   0.015112
# 8  -0.114057
# 9  -0.280958
# 10 -0.408861
# 11 -0.068737
# 12 -0.048442
# 13 -0.337957
# 14 -0.247588
# 15 -0.335556
# 16 -0.538112
# 17 -0.218528
# 18 -0.336066
# 19 -0.432079
#            0
# 0  -1.423442
# 1   3.600282
# 2   0.603547
# 3   1.363073
# 4   0.258077
# 5   0.471442
# 6  -0.244640
# 7   0.115302
# 8   0.073204
# 9  -0.233823
# 10 -0.527622
# 11 -0.276157
# 12 -0.108103
# 13 -0.558888
# 14 -0.506533
# 15 -0.290156
# 16 -0.632870
# 17 -0.525999
# 18 -0.547670
# 19 -0.609024
#            0
# 0  -2.137594
# 1   3.797131
# 2  -0.164557
# 3   0.354762
# 4   0.618772
# 5  -0.133785
# 6  -0.147584
# 7  -0.117709
# 8  -0.217767
# 9  -0.159395
# 10 -0.244778
# 11 -0.163648
# 12 -0.103059
# 13 -0.051047
# 14 -0.023671
# 15 -0.231234
# 16 -0.235059
# 17 -0.224415
# 18 -0.160343
# 19 -0.255019
#            0
# 0  -3.158458
# 1   2.830344
# 2  -0.378189
# 3   1.069917
# 4   0.510121
# 5   0.280058
# 6   0.065859
# 7   0.135079
# 8  -0.445273
# 9  -0.144816
# 10  0.034293
# 11 -0.044507
# 12 -0.011571
# 13  0.079651
# 14 -0.147376
# 15 -0.130768
# 16 -0.140399
# 17 -0.103252
# 18 -0.047814
# 19 -0.252897
#            0
# 0  -0.254157
# 1   3.327647
# 2   0.789701
# 3   2.115935
# 4  -0.303817
# 5   0.654390
# 6  -0.342643
# 7  -0.051810
# 8  -0.520163
# 9  -0.301726
# 10 -0.680784
# 11 -0.274037
# 12 -0.683576
# 13 -0.575826
# 14 -0.390699
# 15 -0.511843
# 16 -0.442321
# 17 -0.457387
# 18 -0.530318
# 19 -0.566567
#            0
# 0  -2.315236
# 1   3.069490
# 2  -0.424578
# 3   1.932666
# 4   0.201525
# 5   0.525032
# 6  -0.305798
# 7   0.180267
# 8  -0.298012
# 9  -0.429882
# 10 -0.245016
# 11 -0.153832
# 12 -0.150707
# 13 -0.332034
# 14 -0.066941
# 15 -0.141031
# 16 -0.475945
# 17 -0.274510
# 18 -0.149338
# 19 -0.146122
#            0
# 0  -1.932466
# 1   3.456790
# 2   0.018998
# 3   1.499349
# 4  -0.130354
# 5   0.682951
# 6  -0.227244
# 7   0.132179
# 8  -0.523352
# 9  -0.174011
# 10 -0.256145
# 11 -0.423896
# 12 -0.489267
# 13 -0.457615
# 14 -0.418625
# 15 -0.305134
# 16 -0.040971
# 17 -0.487011
# 18  0.096603
# 19 -0.020780
#            0
# 0  -2.100928
# 1   3.812491
# 2   0.318477
# 3   0.259378
# 4   0.425021
# 5  -0.150880
# 6  -0.173141
# 7  -0.206347
# 8  -0.411178
# 9  -0.207360
# 10 -0.275978
# 11  0.131263
# 12 -0.279875
# 13 -0.135116
# 14 -0.180599
# 15 -0.314127
# 16 -0.190380
# 17 -0.068518
# 18 -0.114701
# 19 -0.137503
#            0
# 0  -2.148725
# 1   3.465681
# 2   0.433819
# 3   1.188513
# 4  -0.029676
# 5   0.203728
# 6   0.162025
# 7   0.170284
# 8  -0.023610
# 9  -0.014912
# 10 -0.261826
# 11 -0.074835
# 12 -0.216592
# 13 -0.416723
# 14 -0.131088
# 15  0.006966
# 16 -0.487054
# 17 -0.558389
# 18 -0.698973
# 19 -0.568614
#            0
# 0  -2.643707
# 1   3.183150
# 2  -0.083541
# 3   1.201855
# 4   0.029278
# 5   0.452861
# 6   0.291783
# 7  -0.014909
# 8  -0.399781
# 9   0.072427
# 10 -0.310915
# 11  0.375440
# 12 -0.285973
# 13 -0.283694
# 14 -0.127623
# 15 -0.545137
# 16 -0.094015
# 17 -0.392612
# 18 -0.256988
# 19 -0.167899
#            0
# 0  -2.929231
# 1   3.320232
# 2   0.114315
# 3  -0.183584
# 4   0.454194
# 5   0.016933
# 6  -0.195695
# 7   0.044368
# 8  -0.094802
# 9   0.004335
# 10 -0.079423
# 11 -0.245240
# 12 -0.125065
# 13 -0.026415
# 14 -0.047779
# 15 -0.036363
# 16 -0.052790
# 17 -0.017344
# 18  0.054023
# 19  0.025330
#            0
# 0  -3.222297
# 1   2.870908
# 2   0.467481
# 3   0.880431
# 4   0.188889
# 5   0.288572
# 6  -0.007649
# 7  -0.122472
# 8  -0.139898
# 9  -0.188816
# 10 -0.132628
# 11  0.029068
# 12 -0.010962
# 13 -0.215237
# 14 -0.090397
# 15 -0.082969
# 16  0.005822
# 17 -0.292915
# 18 -0.093944
# 19 -0.130988
#            0
# 0  -2.701918
# 1   3.264779
# 2   0.036402
# 3   1.080162
# 4   0.515786
# 5   0.248476
# 6  -0.113483
# 7  -0.116923
# 8  -0.332134
# 9  -0.251627
# 10 -0.256023
# 11 -0.276952
# 12 -0.071147
# 13 -0.045115
# 14 -0.098077
# 15 -0.140179
# 16 -0.187925
# 17 -0.232326
# 18 -0.273035
# 19 -0.048742
#            0
# 0  -2.976927
# 1   3.181526
# 2   0.216791
# 3   0.331841
# 4   0.741365
# 5   0.004100
# 6  -0.132205
# 7   0.065137
# 8  -0.103024
# 9  -0.099127
# 10  0.040405
# 11 -0.093917
# 12 -0.098800
# 13  0.048312
# 14 -0.071411
# 15 -0.134641
# 16 -0.211446
# 17 -0.210176
# 18 -0.313402
# 19 -0.184402
#            0
# 0  -2.136606
# 1   3.601072
# 2  -0.058029
# 3   1.115720
# 4  -0.001870
# 5   0.444798
# 6  -0.233333
# 7   0.142282
# 8  -0.407216
# 9  -0.508005
# 10 -0.068457
# 11 -0.179239
# 12 -0.102337
# 13 -0.052445
# 14 -0.414537
# 15 -0.231875
# 16 -0.081233
# 17 -0.195489
# 18 -0.345182
# 19 -0.288020
#            0
# 0  -2.098638
# 1   3.536653
# 2   0.516594
# 3   1.049566
# 4  -0.444548
# 5   0.466118
# 6  -0.314002
# 7   0.331089
# 8  -0.301507
# 9  -0.110607
# 10 -0.480175
# 11  0.002958
# 12 -0.438787
# 13 -0.108945
# 14 -0.314468
# 15 -0.330802
# 16 -0.423864
# 17 -0.401109
# 18 -0.073582
# 19 -0.061946
#            0
# 0  -1.654743
# 1   3.515795
# 2   0.673033
# 3   1.450164
# 4  -0.119687
# 5   0.323600
# 6  -0.349293
# 7  -0.063516
# 8  -0.784040
# 9  -0.111966
# 10 -0.457963
# 11 -0.154510
# 12 -0.557662
# 13 -0.317226
# 14  0.030924
# 15 -0.139735
# 16  0.008342
# 17 -0.037638
# 18 -0.725489
# 19 -0.528390
#            0
# 0  -2.692777
# 1   3.151630
# 2  -0.601691
# 3   1.337345
# 4   0.117268
# 5   0.071554
# 6  -0.343117
# 7   0.233394
# 8  -0.534235
# 9   0.050104
# 10 -0.307003
# 11 -0.202537
# 12 -0.021641
# 13 -0.059347
# 14 -0.129516
# 15  0.066248
# 16  0.005781
# 17 -0.095859
# 18 -0.112181
# 19  0.066581
#            0
# 0  -0.938339
# 1   3.544214
# 2   0.400445
# 3   1.840920
# 4  -0.112148
# 5   0.375710
# 6  -0.698773
# 7   0.119090
# 8  -0.625334
# 9  -0.207491
# 10 -0.595711
# 11 -0.221469
# 12 -0.187027
# 13  0.075465
# 14 -0.109990
# 15 -0.476850
# 16 -0.446901
# 17 -0.707281
# 18 -0.462083
# 19 -0.566446
#            0
# 0  -1.616385
# 1   3.654773
# 2   0.785048
# 3   1.070389
# 4  -0.188962
# 5   0.494549
# 6  -0.352130
# 7   0.163631
# 8  -0.560416
# 9  -0.267706
# 10 -0.647892
# 11 -0.270641
# 12 -0.585787
# 13 -0.400088
# 14 -0.410388
# 15  0.015688
# 16 -0.169137
# 17 -0.458135
# 18 -0.042040
# 19 -0.214369
#            0
# 0  -2.113841
# 1   3.388296
# 2   0.677245
# 3   1.493432
# 4   0.175377
# 5   0.231987
# 6  -0.167577
# 7  -0.137244
# 8  -0.031153
# 9  -0.251264
# 10 -0.462458
# 11 -0.238422
# 12 -0.276089
# 13 -0.293287
# 14 -0.206077
# 15 -0.455327
# 16 -0.339978
# 17 -0.172631
# 18 -0.384179
# 19 -0.436809
#            0
# 0  -0.994460
# 1   3.358508
# 2  -0.239839
# 3   2.315883
# 4   0.141511
# 5   0.513440
# 6  -0.546613
# 7  -0.256253
# 8  -0.228532
# 9  -0.346247
# 10 -0.429207
# 11 -0.315399
# 12 -0.255139
# 13 -0.442766
# 14 -0.549417
# 15 -0.158551
# 16 -0.442325
# 17 -0.399793
# 18 -0.347599
# 19 -0.377204
#            0
# 0  -3.308702
# 1   2.812086
# 2   0.383524
# 3   0.362962
# 4   0.480638
# 5  -0.174657
# 6  -0.205299
# 7  -0.122565
# 8  -0.346763
# 9  -0.347596
# 10 -0.273120
# 11 -0.251919
# 12 -0.050192
# 13  0.234661
# 14  0.128176
# 15  0.115533
# 16  0.133423
# 17  0.166608
# 18  0.116474
# 19  0.146730
#            0
# 0  -2.272421
# 1   3.114848
# 2  -0.274431
# 3   1.838267
# 4  -0.042872
# 5   0.136314
# 6  -0.321090
# 7   0.213694
# 8  -0.757358
# 9  -0.457793
# 10 -0.327940
# 11 -0.658108
# 12 -0.157923
# 13 -0.016495
# 14  0.257020
# 15 -0.039002
# 16 -0.064084
# 17 -0.068464
# 18  0.148272
# 19 -0.250432
#            0
# 0  -2.656658
# 1   3.262033
# 2   0.831933
# 3   0.961474
# 4   0.138706
# 5  -0.104072
# 6   0.001614
# 7  -0.353305
# 8  -0.308853
# 9  -0.065115
# 10  0.043468
# 11 -0.188040
# 12 -0.427908
# 13 -0.154593
# 14 -0.271599
# 15 -0.181681
# 16 -0.105720
# 17 -0.197518
# 18 -0.067982
# 19 -0.156184
#            0
# 0  -1.616367
# 1   3.526296
# 2   0.087407
# 3   1.639688
# 4  -0.065165
# 5   0.604731
# 6  -0.264778
# 7  -0.305474
# 8  -0.719676
# 9  -0.182094
# 10 -0.419942
# 11 -0.567600
# 12 -0.541229
# 13  0.001957
# 14 -0.252948
# 15 -0.122203
# 16  0.115306
# 17 -0.236247
# 18 -0.348258
# 19 -0.333403
#            0
# 0  -1.994285
# 1   3.495033
# 2  -0.168651
# 3   1.599759
# 4  -0.117244
# 5   0.218907
# 6  -0.378480
# 7  -0.086880
# 8  -0.444727
# 9  -0.144214
# 10 -0.567383
# 11 -0.170029
# 12 -0.527949
# 13  0.050716
# 14 -0.147423
# 15 -0.009626
# 16 -0.303783
# 17 -0.178534
# 18 -0.100672
# 19 -0.024538
#            0
# 0  -2.135789
# 1   3.266683
# 2   0.346427
# 3   1.794560
# 4  -0.049970
# 5   0.208681
# 6   0.006136
# 7  -0.086518
# 8  -0.543933
# 9  -0.300845
# 10 -0.200970
# 11 -0.645261
# 12 -0.374725
# 13 -0.163501
# 14  0.057645
# 15 -0.355667
# 16 -0.063739
# 17 -0.119613
# 18 -0.248550
# 19 -0.391051
#            0
# 0  -0.544188
# 1   3.320193
# 2   1.094791
# 3   1.794532
# 4   0.253296
# 5   0.601267
# 6  -0.460028
# 7   0.135264
# 8  -0.279896
# 9  -0.344411
# 10 -0.289156
# 11 -0.324660
# 12 -0.377419
# 13 -0.695310
# 14 -0.565974
# 15 -0.754775
# 16 -0.515917
# 17 -0.821651
# 18 -0.538800
# 19 -0.687158
#            0
# 0  -0.064329
# 1   3.551064
# 2   1.025053
# 3   1.639762
# 4   0.245886
# 5   0.181404
# 6  -0.439646
# 7  -0.003553
# 8  -0.164574
# 9  -0.435440
# 10 -0.598491
# 11 -0.383868
# 12 -0.481744
# 13 -0.602545
# 14 -0.705300
# 15 -0.651717
# 16 -0.569119
# 17 -0.548099
# 18 -0.475422
# 19 -0.519322
#            0
# 0  -2.814283
# 1   3.215182
# 2   0.038400
# 3   0.989439
# 4   0.463320
# 5   0.150335
# 6   0.153281
# 7  -0.099612
# 8  -0.097992
# 9  -0.080863
# 10 -0.162210
# 11  0.003365
# 12 -0.042929
# 13 -0.139692
# 14 -0.183967
# 15 -0.226327
# 16 -0.265247
# 17 -0.296245
# 18 -0.271335
# 19 -0.332621
#            0
# 0  -1.556311
# 1   3.855683
# 2   0.200986
# 3   1.145823
# 4  -0.233621
# 5  -0.097905
# 6   0.347732
# 7  -0.216593
# 8  -0.364102
# 9  -0.295203
# 10 -0.264203
# 11 -0.421619
# 12 -0.534546
# 13 -0.149982
# 14 -0.284574
# 15 -0.270383
# 16 -0.133757
# 17 -0.208855
# 18 -0.278420
# 19 -0.240150
#            0
# 0  -2.474560
# 1   3.098003
# 2  -0.051052
# 3   1.578806
# 4   0.327147
# 5   0.730058
# 6   0.239772
# 7  -0.240525
# 8  -0.243073
# 9  -0.150353
# 10 -0.296982
# 11 -0.447273
# 12 -0.396464
# 13 -0.061876
# 14 -0.125342
# 15 -0.189377
# 16 -0.326252
# 17 -0.194782
# 18 -0.402779
# 19 -0.373098
#            0
# 0  -2.177941
# 1   3.310171
# 2   0.360799
# 3   1.722998
# 4  -0.016169
# 5   0.186298
# 6  -0.119158
# 7  -0.009618
# 8  -0.339646
# 9  -0.262153
# 10 -0.184684
# 11 -0.519469
# 12 -0.454264
# 13 -0.019621
# 14 -0.108034
# 15 -0.304638
# 16 -0.282804
# 17 -0.398353
# 18 -0.051061
# 19 -0.332652
#            0
# 0  -2.818924
# 1   3.292465
# 2   0.256965
# 3   0.334199
# 4   0.808516
# 5   0.170401
# 6  -0.078582
# 7  -0.052592
# 8  -0.131707
# 9  -0.199409
# 10 -0.196469
# 11 -0.124984
# 12 -0.162177
# 13 -0.073129
# 14 -0.144993
# 15 -0.120408
# 16 -0.076818
# 17 -0.173686
# 18 -0.252190
# 19 -0.256476
#            0
# 0  -2.999674
# 1   3.103510
# 2  -0.231277
# 3   0.863607
# 4   0.543468
# 5  -0.093311
# 6   0.180953
# 7  -0.111213
# 8  -0.078490
# 9  -0.096695
# 10 -0.292491
# 11  0.005706
# 12 -0.013352
# 13 -0.082919
# 14 -0.003882
# 15 -0.144267
# 16 -0.090170
# 17 -0.060679
# 18 -0.225685
# 19 -0.173137
#            0
# 0  -2.788801
# 1   3.191719
# 2  -0.696477
# 3   0.972918
# 4   0.061769
# 5   0.503646
# 6  -0.182347
# 7   0.065704
# 8  -0.304624
# 9  -0.126179
# 10 -0.100564
# 11 -0.214770
# 12 -0.221590
# 13 -0.113602
# 14  0.090121
# 15 -0.216572
# 16  0.107103
# 17 -0.083774
# 18  0.086319
# 19 -0.030000
#            0
# 0  -0.615618
# 1   3.501873
# 2   0.880160
# 3   1.701233
# 4  -0.405258
# 5   0.697420
# 6  -0.504546
# 7   0.187118
# 8  -0.518660
# 9  -0.078679
# 10 -0.471944
# 11 -0.205201
# 12 -0.565865
# 13 -0.602302
# 14 -0.457830
# 15 -0.633746
# 16 -0.426646
# 17 -0.508098
# 18 -0.504165
# 19 -0.469247
#            0
# 0  -1.927661
# 1   3.309605
# 2  -0.025137
# 3   1.975239
# 4  -0.028167
# 5   0.494214
# 6  -0.045936
# 7  -0.154030
# 8  -0.358777
# 9  -0.285661
# 10 -0.330463
# 11 -0.328159
# 12 -0.365187
# 13 -0.340851
# 14 -0.182332
# 15 -0.259717
# 16 -0.303489
# 17 -0.186972
# 18 -0.191267
# 19 -0.465251
#            0
# 0  -1.680933
# 1   3.766705
# 2   0.132715
# 3   1.281490
# 4  -0.106208
# 5   0.168774
# 6  -0.347530
# 7   0.053628
# 8  -0.488992
# 9  -0.246059
# 10 -0.483000
# 11 -0.361900
# 12 -0.306391
# 13 -0.149719
# 14 -0.091644
# 15 -0.020904
# 16 -0.188600
# 17 -0.471283
# 18 -0.302750
# 19 -0.157401
#            0
# 0  -1.820636
# 1   3.615331
# 2  -0.031176
# 3   1.500489
# 4   0.311025
# 5   0.023068
# 6  -0.259866
# 7   0.027125
# 8  -0.198263
# 9  -0.296817
# 10 -0.371519
# 11 -0.407552
# 12 -0.371039
# 13 -0.237520
# 14 -0.388489
# 15 -0.079936
# 16  0.042392
# 17 -0.394799
# 18 -0.194723
# 19 -0.467094
#            0
# 0  -1.027895
# 1   3.582799
# 2   0.287165
# 3   1.582619
# 4   0.281784
# 5   0.776106
# 6  -0.346141
# 7  -0.282531
# 8  -0.232325
# 9  -0.170009
# 10 -0.902231
# 11 -0.414097
# 12 -0.632432
# 13 -0.437123
# 14 -0.364512
# 15  0.021943
# 16 -0.163986
# 17 -0.520261
# 18 -0.584580
# 19 -0.454294
#            0
# 0  -1.943053
# 1   3.450457
# 2   0.063694
# 3   1.569041
# 4   0.320440
# 5   0.391436
# 6  -0.595208
# 7  -0.100011
# 8  -0.275420
# 9  -0.187094
# 10 -0.391968
# 11 -0.125926
# 12 -0.308790
# 13  0.117927
# 14 -0.065352
# 15 -0.124094
# 16 -0.430659
# 17 -0.532204
# 18 -0.478447
# 19 -0.354767
#            0
# 0  -2.593429
# 1   3.363677
# 2  -0.418223
# 3   1.082775
# 4   0.285893
# 5  -0.042629
# 6   0.337318
# 7  -0.226608
# 8   0.036316
# 9  -0.028240
# 10 -0.233085
# 11 -0.053386
# 12 -0.227672
# 13 -0.218582
# 14 -0.152378
# 15 -0.130558
# 16 -0.142657
# 17 -0.241231
# 18 -0.258501
# 19 -0.138800
#            0
# 0  -1.852158
# 1   3.768198
# 2  -0.104150
# 3   1.105916
# 4   0.095152
# 5  -0.417527
# 6   0.292955
# 7  -0.014235
# 8  -0.084466
# 9  -0.272330
# 10 -0.479036
# 11 -0.298965
# 12 -0.302943
# 13 -0.389424
# 14 -0.199455
# 15 -0.248873
# 16 -0.196090
# 17 -0.223494
# 18  0.003092
# 19 -0.182166
#            0
# 0  -1.963919
# 1   3.714567
# 2   0.717079
# 3   0.594004
# 4  -0.058292
# 5   0.555821
# 6  -0.270009
# 7  -0.167853
# 8  -0.146482
# 9   0.101149
# 10 -0.341681
# 11 -0.039288
# 12 -0.374603
# 13 -0.341793
# 14 -0.312271
# 15 -0.356083
# 16 -0.348068
# 17 -0.339773
# 18 -0.348472
# 19 -0.274032
#            0
# 0  -2.502040
# 1   3.340272
# 2   0.323091
# 3   1.052418
# 4  -0.114112
# 5   0.345995
# 6  -0.006102
# 7   0.111009
# 8  -0.026832
# 9  -0.108972
# 10 -0.518280
# 11 -0.581989
# 12 -0.505050
# 13 -0.306881
# 14 -0.324120
# 15  0.162526
# 16 -0.128710
# 17 -0.307078
# 18 -0.020802
# 19  0.115656
#            0
# 0  -2.574025
# 1   3.510399
# 2   0.354632
# 3   0.499889
# 4   0.472337
# 5   0.011969
# 6  -0.035082
# 7  -0.080007
# 8  -0.048937
# 9  -0.109992
# 10 -0.252077
# 11 -0.082262
# 12 -0.179759
# 13 -0.221435
# 14 -0.140175
# 15 -0.202529
# 16 -0.271798
# 17 -0.179592
# 18 -0.215320
# 19 -0.256236
#            0
# 0  -2.398526
# 1   3.469503
# 2  -0.322095
# 3   1.167556
# 4  -0.002367
# 5   0.273735
# 6  -0.149535
# 7   0.163785
# 8  -0.256518
# 9  -0.022630
# 10 -0.194750
# 11 -0.343238
# 12 -0.332673
# 13 -0.227658
# 14 -0.133411
# 15 -0.422799
# 16 -0.034918
# 17 -0.187461
# 18 -0.018903
# 19 -0.027095
#            0
# 0  -2.718124
# 1   2.855603
# 2  -0.156675
# 3   1.684085
# 4   0.532258
# 5   0.459273
# 6  -0.551662
# 7   0.078032
# 8  -0.316771
# 9  -0.251116
# 10 -0.405590
# 11 -0.418040
# 12 -0.271472
# 13 -0.185116
# 14 -0.043988
# 15  0.114317
# 16  0.139226
# 17 -0.081004
# 18 -0.360305
# 19 -0.102931
#            0
# 0  -2.734725
# 1   3.376867
# 2   0.336030
# 3   0.573473
# 4   0.546017
# 5   0.023934
# 6  -0.110620
# 7  -0.048008
# 8  -0.243649
# 9  -0.199522
# 10 -0.244600
# 11 -0.225151
# 12 -0.129350
# 13 -0.222488
# 14 -0.102301
# 15 -0.125776
# 16 -0.133409
# 17 -0.065153
# 18 -0.105124
# 19 -0.166446
#            0
# 0  -2.714525
# 1   3.289351
# 2   0.451307
# 3   0.779947
# 4   0.632219
# 5   0.072551
# 6   0.097714
# 7  -0.139882
# 8  -0.056930
# 9  -0.208042
# 10 -0.276882
# 11 -0.191856
# 12 -0.087230
# 13 -0.254844
# 14 -0.238058
# 15 -0.151535
# 16 -0.222549
# 17 -0.275546
# 18 -0.262371
# 19 -0.242839
#            0
# 0  -1.915679
# 1   3.495659
# 2   0.076691
# 3   1.590578
# 4   0.087962
# 5   0.323003
# 6  -0.189243
# 7  -0.014932
# 8  -0.459204
# 9  -0.258721
# 10 -0.452791
# 11 -0.463731
# 12 -0.325635
# 13 -0.551406
# 14  0.011103
# 15 -0.206947
# 16  0.116954
# 17 -0.343084
# 18 -0.193850
# 19 -0.326727
#            0
# 0  -0.950175
# 1   3.043226
# 2   0.778747
# 3   2.227348
# 4  -0.201968
# 5   0.830347
# 6  -0.599954
# 7   0.349348
# 8  -0.753486
# 9  -0.210711
# 10 -0.635466
# 11 -0.445568
# 12 -0.771111
# 13 -0.351838
# 14 -0.109730
# 15 -0.529952
# 16 -0.238448
# 17 -0.550806
# 18 -0.236054
# 19 -0.643749
#            0
# 0  -2.520070
# 1   3.413088
# 2  -0.156602
# 3   1.178879
# 4   0.140613
# 5   0.206763
# 6  -0.229510
# 7  -0.083584
# 8  -0.423970
# 9  -0.154336
# 10 -0.256009
# 11 -0.048775
# 12 -0.216382
# 13 -0.174491
# 14 -0.094027
# 15 -0.218221
# 16 -0.020711
# 17 -0.211892
# 18 -0.017861
# 19 -0.112901
#            0
# 0  -2.232826
# 1   3.701219
# 2  -0.076013
# 3   0.787964
# 4   0.127997
# 5   0.026352
# 6   0.008192
# 7  -0.176111
# 8  -0.471247
# 9  -0.024460
# 10 -0.277626
# 11 -0.417193
# 12 -0.125570
# 13 -0.155783
# 14 -0.058664
# 15 -0.256698
# 16 -0.104377
# 17 -0.007017
# 18 -0.061344
# 19 -0.206793
#            0
# 0  -1.937732
# 1   3.601348
# 2  -0.273823
# 3   1.350540
# 4   0.096883
# 5   0.083510
# 6  -0.289138
# 7   0.084604
# 8  -0.594555
# 9   0.062952
# 10 -0.404331
# 11 -0.310779
# 12 -0.547016
# 13  0.044404
# 14  0.008776
# 15 -0.244525
# 16 -0.037450
# 17 -0.524269
# 18 -0.095432
# 19 -0.073968
#            0
# 0  -2.643297
# 1   3.133828
# 2  -0.681990
# 3   1.479433
# 4   0.117492
# 5  -0.022537
# 6   0.062483
# 7   0.204983
# 8  -0.132300
# 9   0.022552
# 10 -0.147629
# 11 -0.298611
# 12 -0.164039
# 13 -0.328725
# 14 -0.335620
# 15  0.058393
# 16 -0.033369
# 17 -0.269234
# 18  0.099097
# 19 -0.120911
#            0
# 0  -2.249568
# 1   3.139389
# 2   0.570946
# 3   1.752102
# 4   0.233499
# 5   0.423193
# 6  -0.286281
# 7   0.202491
# 8  -0.332546
# 9  -0.269619
# 10 -0.513244
# 11 -0.229074
# 12 -0.154151
# 13 -0.359605
# 14 -0.289276
# 15 -0.364681
# 16 -0.225777
# 17 -0.493332
# 18 -0.192749
# 19 -0.361716
#            0
# 0  -3.041390
# 1   2.776447
# 2   0.453160
# 3   1.291681
# 4  -0.215614
# 5   0.452801
# 6  -0.174446
# 7   0.417331
# 8  -0.384269
# 9   0.022868
# 10 -0.459438
# 11  0.230815
# 12 -0.246265
# 13 -0.310782
# 14 -0.176841
# 15 -0.030780
# 16 -0.071828
# 17 -0.169184
# 18 -0.250173
# 19 -0.114092
#            0
# 0  -2.223417
# 1   3.519846
# 2  -0.091920
# 3   1.216478
# 4   0.077891
# 5   0.120532
# 6  -0.079317
# 7   0.299300
# 8  -0.319539
# 9  -0.164417
# 10 -0.039152
# 11 -0.279372
# 12 -0.229600
# 13 -0.510743
# 14 -0.404148
# 15 -0.539697
# 16 -0.218356
# 17 -0.188039
# 18  0.049059
# 19  0.004612
#            0
# 0  -1.719982
# 1   3.488339
# 2  -0.846993
# 3   1.607009
# 4   0.015827
# 5   0.068356
# 6  -0.182017
# 7  -0.202982
# 8  -0.842711
# 9  -0.552536
# 10 -0.280442
# 11 -0.372914
# 12 -0.070585
# 13 -0.037139
# 14  0.002446
# 15 -0.054591
# 16  0.293564
# 17  0.118333
# 18 -0.044545
# 19 -0.386438
#            0
# 0  -1.709396
# 1   3.381327
# 2   1.008826
# 3   1.703084
# 4  -0.024809
# 5   0.046450
# 6  -0.169509
# 7  -0.097072
# 8  -0.184372
# 9  -0.049502
# 10 -0.447818
# 11 -0.137039
# 12 -0.501032
# 13 -0.484690
# 14 -0.398972
# 15 -0.450501
# 16 -0.308232
# 17 -0.371170
# 18 -0.292457
# 19 -0.513115
#            0
# 0  -2.637352
# 1   3.113233
# 2  -0.318872
# 3   1.663412
# 4  -0.005650
# 5   0.135500
# 6  -0.063297
# 7  -0.029009
# 8  -0.211409
# 9  -0.325195
# 10 -0.051801
# 11 -0.273329
# 12 -0.341901
# 13 -0.100482
# 14  0.058537
# 15 -0.108666
# 16 -0.208936
# 17 -0.197199
# 18 -0.087065
# 19 -0.010518
#            0
# 0  -2.343992
# 1   3.666739
# 2  -0.000408
# 3   0.601853
# 4   0.407147
# 5  -0.146466
# 6   0.001777
# 7  -0.247702
# 8  -0.206653
# 9   0.056798
# 10 -0.287410
# 11 -0.071855
# 12 -0.219529
# 13 -0.280281
# 14 -0.157550
# 15 -0.218099
# 16 -0.163750
# 17  0.005600
# 18 -0.121506
# 19 -0.274712
#            0
# 0  -1.593394
# 1   3.597849
# 2   0.573093
# 3   0.778801
# 4   0.885074
# 5   0.682874
# 6  -0.407503
# 7   0.033101
# 8  -0.320641
# 9  -0.119744
# 10 -0.682330
# 11 -0.389585
# 12 -0.020004
# 13 -0.289120
# 14 -0.663800
# 15 -0.379286
# 16 -0.394656
# 17 -0.444916
# 18 -0.581652
# 19 -0.264160
#            0
# 0  -2.647914
# 1   3.404107
# 2   0.307836
# 3   0.701132
# 4   0.483323
# 5   0.007513
# 6   0.021344
# 7   0.021048
# 8  -0.475551
# 9  -0.203154
# 10 -0.320036
# 11 -0.238479
# 12 -0.103495
# 13 -0.200811
# 14 -0.139341
# 15 -0.173604
# 16 -0.148270
# 17 -0.110676
# 18 -0.069528
# 19 -0.115444
#            0
# 0  -2.534750
# 1   3.397491
# 2   0.146460
# 3   0.808002
# 4   0.875281
# 5  -0.114323
# 6  -0.147668
# 7  -0.025048
# 8  -0.282743
# 9  -0.187751
# 10 -0.044390
# 11 -0.122166
# 12 -0.209826
# 13 -0.149470
# 14 -0.178722
# 15 -0.166339
# 16 -0.229505
# 17 -0.189177
# 18 -0.349069
# 19 -0.296285
#            0
# 0  -2.889159
# 1   3.257194
# 2  -0.090426
# 3   0.602391
# 4   0.613901
# 5  -0.284918
# 6   0.096512
# 7  -0.174016
# 8  -0.003874
# 9  -0.093783
# 10 -0.224955
# 11 -0.092724
# 12 -0.109044
# 13 -0.158709
# 14 -0.135241
# 15 -0.088218
# 16 -0.178688
# 17 -0.098532
# 18  0.009186
# 19  0.043103
#            0
# 0  -2.383421
# 1   3.152459
# 2  -0.504258
# 3   1.766767
# 4   0.140727
# 5   0.320318
# 6  -0.373045
# 7  -0.196582
# 8  -0.399991
# 9  -0.389075
# 10 -0.315003
# 11 -0.436015
# 12 -0.280250
# 13  0.083392
# 14 -0.037235
# 15 -0.055208
# 16  0.023788
# 17 -0.104198
# 18 -0.046594
# 19  0.033426
#            0
# 0  -0.117051
# 1   3.715757
# 2   0.752507
# 3   1.567018
# 4  -0.150505
# 5   0.369673
# 6  -0.356561
# 7  -0.077887
# 8  -0.469854
# 9  -0.374333
# 10 -0.516799
# 11 -0.217333
# 12 -0.504925
# 13 -0.355410
# 14 -0.389079
# 15 -0.601501
# 16 -0.532162
# 17 -0.605414
# 18 -0.554937
# 19 -0.581203
#            0
# 0  -2.173147
# 1   3.521223
# 2   0.380116
# 3   1.120831
# 4   0.026254
# 5   0.227970
# 6  -0.348468
# 7   0.345922
# 8  -0.336797
# 9  -0.014588
# 10 -0.196529
# 11  0.037796
# 12 -0.490080
# 13 -0.064179
# 14 -0.575804
# 15 -0.370809
# 16 -0.266786
# 17 -0.385848
# 18 -0.193002
# 19 -0.244076
#            0
# 0  -2.082784
# 1   3.521537
# 2  -0.172836
# 3   1.274950
# 4   0.157466
# 5   0.552317
# 6  -0.429470
# 7   0.052697
# 8  -0.337112
# 9  -0.113556
# 10 -0.498378
# 11 -0.336038
# 12 -0.358846
# 13  0.102295
# 14  0.003004
# 15 -0.379639
# 16 -0.261651
# 17 -0.019817
# 18 -0.234477
# 19 -0.439662
#            0
# 0  -0.728409
# 1   4.047624
# 2  -0.220233
# 3   1.008827
# 4   0.139543
# 5   0.285929
# 6  -0.348563
# 7   0.053534
# 8  -0.686225
# 9  -0.015410
# 10 -0.252738
# 11 -0.392736
# 12 -0.398116
# 13 -0.359182
# 14 -0.563073
# 15 -0.340359
# 16 -0.354442
# 17 -0.251861
# 18 -0.332660
# 19 -0.291453
#            0
# 0  -2.278070
# 1   3.283588
# 2   0.860910
# 3   1.222977
# 4  -0.102234
# 5   0.487489
# 6  -0.455591
# 7   0.086283
# 8   0.342248
# 9  -0.208781
# 10 -0.330308
# 11 -0.112265
# 12 -0.463002
# 13 -0.342120
# 14 -0.350268
# 15 -0.393485
# 16 -0.436258
# 17 -0.142195
# 18 -0.296550
# 19 -0.372368
#            0
# 0  -1.983807
# 1   3.373180
# 2  -0.481050
# 3   1.798542
# 4  -0.210945
# 5   0.113825
# 6  -0.157392
# 7  -0.012344
# 8  -0.407136
# 9   0.032383
# 10 -0.424388
# 11 -0.556292
# 12 -0.526759
# 13 -0.332500
# 14 -0.177154
# 15 -0.008392
# 16  0.159562
# 17 -0.048054
# 18  0.030565
# 19 -0.181844
#            0
# 0  -2.278061
# 1   3.424024
# 2   0.671313
# 3   1.149739
# 4   0.310950
# 5   0.127354
# 6  -0.300895
# 7   0.290510
# 8  -0.219373
# 9  -0.273137
# 10 -0.253850
# 11 -0.288329
# 12 -0.324075
# 13 -0.421356
# 14 -0.201022
# 15 -0.404479
# 16 -0.301828
# 17 -0.198336
# 18 -0.186915
# 19 -0.322235
#            0
# 0  -2.760859
# 1   3.224943
# 2   0.478888
# 3   1.018422
# 4   0.441438
# 5  -0.132808
# 6   0.086962
# 7   0.017082
# 8  -0.174180
# 9  -0.238419
# 10 -0.138565
# 11 -0.180546
# 12 -0.158331
# 13 -0.231799
# 14 -0.138585
# 15 -0.192987
# 16 -0.280689
# 17 -0.238236
# 18 -0.195447
# 19 -0.206283
#            0
# 0  -2.253700
# 1   3.507818
# 2  -0.005331
# 3   1.266313
# 4   0.141236
# 5   0.419564
# 6  -0.096651
# 7  -0.055031
# 8  -0.200967
# 9  -0.236218
# 10 -0.271356
# 11 -0.323626
# 12 -0.454197
# 13 -0.201400
# 14 -0.172365
# 15 -0.356825
# 16 -0.157722
# 17 -0.174084
# 18 -0.190208
# 19 -0.185252
#            0
# 0  -1.520461
# 1   3.747582
# 2   0.129420
# 3   0.798051
# 4   0.345458
# 5   0.577315
# 6  -0.076547
# 7   0.298670
# 8  -0.650788
# 9  -0.195638
# 10 -0.668282
# 11 -0.158483
# 12 -0.791765
# 13 -0.434050
# 14 -0.664171
# 15 -0.164606
# 16 -0.354728
# 17 -0.221062
# 18 -0.157267
# 19  0.161352
#            0
# 0  -2.539879
# 1   3.578600
# 2   0.093215
# 3   0.092385
# 4   0.649002
# 5  -0.068337
# 6  -0.242329
# 7  -0.155502
# 8  -0.258286
# 9  -0.205477
# 10 -0.113610
# 11 -0.146460
# 12 -0.057988
# 13 -0.029088
# 14 -0.118699
# 15 -0.151943
# 16 -0.090620
# 17 -0.038323
# 18 -0.060009
# 19 -0.136651
#            0
# 0  -2.667741
# 1   3.511437
# 2  -0.163909
# 3  -0.043683
# 4   0.583055
# 5  -0.041623
# 6  -0.053398
# 7   0.030163
# 8  -0.127156
# 9  -0.047758
# 10 -0.259284
# 11 -0.146141
# 12 -0.098945
# 13 -0.050533
# 14 -0.158754
# 15 -0.126514
# 16  0.024272
# 17  0.000713
# 18 -0.127337
# 19 -0.036866
#            0
# 0  -0.683604
# 1   3.535930
# 2   1.000993
# 3   1.571185
# 4  -0.375700
# 5   0.740095
# 6  -0.108614
# 7  -0.209690
# 8  -0.528949
# 9  -0.433913
# 10 -0.336578
# 11 -0.606592
# 12 -0.207340
# 13 -0.671145
# 14 -0.286435
# 15 -0.730046
# 16 -0.435168
# 17 -0.419683
# 18 -0.579796
# 19 -0.234951
#            0
# 0  -2.505850
# 1   2.820479
# 2   0.105474
# 3   1.817558
# 4   0.070928
# 5   0.179595
# 6   0.598168
# 7  -0.268967
# 8  -0.847851
# 9   0.035637
# 10 -0.568291
# 11 -0.485357
# 12 -0.571838
# 13 -0.055164
# 14  0.113481
# 15  0.293178
# 16  0.107349
# 17 -0.325714
# 18 -0.140393
# 19 -0.372424
#            0
# 0  -2.798064
# 1   3.350375
# 2  -0.222967
# 3  -0.031240
# 4   0.850751
# 5   0.025147
# 6  -0.198775
# 7   0.019591
# 8  -0.135075
# 9  -0.165162
# 10 -0.178598
# 11 -0.096700
# 12  0.016938
# 13  0.044347
# 14 -0.108613
# 15 -0.093335
# 16 -0.063602
# 17 -0.106720
# 18 -0.053224
# 19 -0.055075
#            0
# 0  -2.483748
# 1   3.528878
# 2   0.201903
# 3   0.854662
# 4   0.225635
# 5  -0.044470
# 6  -0.032918
# 7  -0.117590
# 8  -0.122731
# 9   0.156454
# 10 -0.148846
# 11 -0.192461
# 12 -0.278465
# 13 -0.171109
# 14 -0.233313
# 15 -0.270740
# 16 -0.164100
# 17 -0.301057
# 18 -0.256524
# 19 -0.149461
#            0
# 0  -3.223234
# 1   2.979136
# 2   0.007432
# 3   0.638339
# 4   0.328569
# 5  -0.134720
# 6  -0.063272
# 7  -0.233064
# 8  -0.216572
# 9  -0.110899
# 10 -0.101532
# 11 -0.033004
# 12 -0.157394
# 13 -0.059788
# 14  0.109902
# 15  0.036608
# 16  0.110274
# 17  0.135395
# 18  0.011493
# 19 -0.023668
#            0
# 0  -0.832049
# 1   3.223136
# 2   1.129070
# 3   1.885334
# 4   0.182902
# 5   0.780247
# 6  -0.190023
# 7   0.037614
# 8  -0.392318
# 9  -0.332642
# 10 -0.379896
# 11 -0.338559
# 12 -0.648335
# 13 -0.610391
# 14 -0.570452
# 15 -0.640259
# 16 -0.677178
# 17 -0.526666
# 18 -0.644207
# 19 -0.455329
#            0
# 0  -1.445760
# 1   3.571089
# 2   0.158404
# 3   1.728761
# 4   0.024756
# 5   0.341830
# 6  -0.567449
# 7   0.170388
# 8  -0.501523
# 9  -0.153780
# 10 -0.500126
# 11 -0.599503
# 12 -0.386849
# 13 -0.166021
# 14 -0.388571
# 15 -0.273875
# 16  0.037492
# 17 -0.320499
# 18 -0.457430
# 19 -0.271333
#            0
# 0  -3.471350
# 1   2.612824
# 2   0.193254
# 3   0.630106
# 4   0.314417
# 5  -0.048916
# 6   0.075465
# 7  -0.196501
# 8  -0.361602
# 9  -0.184153
# 10 -0.179439
# 11 -0.360280
# 12 -0.079762
# 13  0.102876
# 14  0.080066
# 15  0.233384
# 16  0.294746
# 17  0.169828
# 18  0.148392
# 19  0.026646
#            0
# 0  -2.180540
# 1   3.497730
# 2   0.410704
# 3   1.077042
# 4  -0.160900
# 5   0.661235
# 6  -0.434589
# 7  -0.203150
# 8  -0.415334
# 9  -0.440844
# 10 -0.428405
# 11 -0.425028
# 12 -0.399852
# 13 -0.091944
# 14 -0.068501
# 15 -0.231422
# 16 -0.074146
# 17 -0.054205
# 18  0.086944
# 19 -0.124796
#            0
# 0  -1.763570
# 1   3.666784
# 2   0.692524
# 3   0.950754
# 4  -0.046624
# 5   0.376057
# 6  -0.446233
# 7   0.203122
# 8  -0.612129
# 9  -0.141516
# 10 -0.618916
# 11  0.026569
# 12 -0.344727
# 13 -0.042863
# 14 -0.502728
# 15 -0.229236
# 16 -0.531673
# 17 -0.274270
# 18 -0.023523
# 19 -0.337802
#            0
# 0  -1.801948
# 1   3.827591
# 2   0.539612
# 3   0.755432
# 4  -0.172409
# 5   0.275729
# 6  -0.286854
# 7  -0.104550
# 8  -0.418633
# 9  -0.129920
# 10 -0.538059
# 11 -0.016974
# 12 -0.445347
# 13 -0.276604
# 14 -0.147671
# 15 -0.290571
# 16 -0.203910
# 17 -0.312127
# 18 -0.064166
# 19 -0.188620
#            0
# 0  -2.303810
# 1   3.246548
# 2   0.206967
# 3   1.606219
# 4   0.157865
# 5   0.356623
# 6   0.196713
# 7   0.029269
# 8  -0.587152
# 9   0.011646
# 10 -0.479025
# 11 -0.192723
# 12 -0.384400
# 13 -0.386226
# 14 -0.238816
# 15 -0.351501
# 16 -0.083852
# 17 -0.319063
# 18 -0.348388
# 19 -0.136893
#            0
# 0  -1.960924
# 1   3.758284
# 2  -0.205360
# 3   0.968740
# 4   0.301544
# 5  -0.206674
# 6  -0.009493
# 7  -0.297531
# 8  -0.254460
# 9  -0.462537
# 10 -0.410881
# 11 -0.026567
# 12  0.019281
# 13  0.056719
# 14 -0.107947
# 15 -0.244038
# 16 -0.310981
# 17 -0.015470
# 18 -0.169029
# 19 -0.422676
#            0
# 0  -2.946509
# 1   3.292125
# 2  -0.007600
# 3  -0.170053
# 4   0.531681
# 5   0.114836
# 6   0.067614
# 7   0.059549
# 8   0.022829
# 9  -0.041655
# 10  0.019840
# 11 -0.025363
# 12 -0.116304
# 13 -0.061780
# 14  0.026381
# 15 -0.099902
# 16 -0.120103
# 17 -0.148468
# 18 -0.184371
# 19 -0.212748
#            0
# 0  -1.912091
# 1   2.873836
# 2  -0.313599
# 3   2.394835
# 4   0.038165
# 5   0.441565
# 6   0.330072
# 7  -0.121799
# 8  -0.657720
# 9  -0.259910
# 10 -0.615851
# 11 -0.475637
# 12 -0.771701
# 13  0.066776
# 14 -0.199511
# 15 -0.018340
# 16 -0.066433
# 17 -0.276383
# 18 -0.244082
# 19 -0.212192
#            0
# 0  -1.953422
# 1   3.353753
# 2  -0.456109
# 3   1.737003
# 4  -0.157727
# 5   0.063273
# 6  -0.147090
# 7   0.211566
# 8  -0.146981
# 9   0.102864
# 10 -0.837647
# 11  0.005695
# 12 -0.044074
# 13 -0.526756
# 14 -0.363445
# 15 -0.007151
# 16  0.179010
# 17 -0.206501
# 18 -0.591340
# 19 -0.214922
#            0
# 0  -0.096313
# 1   3.488109
# 2   1.364949
# 3   1.504328
# 4  -0.387721
# 5   0.217140
# 6  -0.469737
# 7   0.205598
# 8  -0.425370
# 9  -0.273108
# 10 -0.632613
# 11 -0.057236
# 12 -0.588684
# 13 -0.619199
# 14 -0.347702
# 15 -0.571234
# 16 -0.668814
# 17 -0.444504
# 18 -0.459654
# 19 -0.738235
#            0
# 0  -2.540278
# 1   3.374880
# 2   0.275733
# 3   1.009841
# 4   0.248073
# 5   0.171277
# 6  -0.102475
# 7  -0.248713
# 8  -0.427277
# 9  -0.523186
# 10 -0.351865
# 11 -0.233643
# 12 -0.460256
# 13 -0.164811
# 14 -0.007450
# 15  0.005983
# 16  0.029971
# 17 -0.124488
# 18  0.087247
# 19 -0.018563

# %% [markdown]
# MFCC Combiner here

# %%
import os
import pandas as pd

# Path to the folder containing the 115 MFCC CSV files
folder_path = './MFCC_Max'  # Update with your folder path

# Initialize an empty list to store data from all songs
mfcc_data_list = []
file_names = []  # List to store the file names

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the MFCC file
        file_path = os.path.join(folder_path, file_name)
        mfcc_data = pd.read_csv(file_path, header=None)
        
        # Append the MFCC coefficients as a row in the list
        mfcc_data_list.append(mfcc_data[0].values)
        
        # Store the file name (without .csv) to keep track of which song it is
        file_names.append(file_name.replace('.csv', ''))

# Convert list to DataFrame (115 rows, 20 columns)
mfcc_df = pd.DataFrame(mfcc_data_list)

mfcc_df.to_csv('MFCC_max_20.csv', index=False)


# Add file names as an additional column for tracking
mfcc_df['Song'] = file_names

# Save to a new CSV file with song names
mfcc_df.to_csv('MFCC_max_20_with_Song_Names.csv', index=False)

print(f"Data shape: {mfcc_df.shape}")
# Out:
# Data shape: (115, 21)

# %% [markdown]
# PCA and tsne

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt



import pandas as pd

mfcc_df = pd.read_csv('MFCC_max_20_with_Song_Names.csv')

song_names = mfcc_df['Song']  # Save the 'Song' column
mfcc_df = mfcc_df.drop(columns=['Song'])  # Use only the MFCC coefficients for PCA and t-SNE
print(mfcc_df.head())

# Step 1: Apply PCA to reduce dimensionality to, say, 10 components


pca = PCA(n_components=10)
mfcc_pca = pca.fit_transform(mfcc_df)


# Step 2: Apply t-SNE on the reduced data from PCA
tsne = TSNE(n_components=2, perplexity=45, random_state=69)
mfcc_tsne_pca = tsne.fit_transform(mfcc_pca)

# Convert t-SNE result to a DataFrame for easy handling
mfcc_tsne_pca_df = pd.DataFrame(mfcc_tsne_pca, columns=['Dimension 1', 'Dimension 2'])


# Plot the results of t-SNE after PCA
plt.figure(figsize=(8, 6))
plt.scatter(mfcc_tsne_pca_df['Dimension 1'], mfcc_tsne_pca_df['Dimension 2'], c='blue', edgecolor='k')
plt.title('t-SNE after PCA on 115 Songs MFCCs')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

mfcc_tsne_pca_df['Song'] = song_names  # Add the 'Song' column back to the t-SNE results

mfcc_tsne_pca_df.to_csv('MFCCtsnePCA_max.csv')
# Out:
#           0         1         2         3         4         5         6  \
# 0 -2.177941  3.310171  0.360799  1.722998 -0.016169  0.186298 -0.119158
# 1 -1.963919  3.714567  0.717079  0.594004 -0.058292  0.555821 -0.270009
# 2 -3.041390  2.776447  0.453160  1.291681 -0.215614  0.452801 -0.174446
# 3 -2.249568  3.139389  0.570946  1.752102  0.233499  0.423193 -0.286281
# 4 -1.852158  3.768198 -0.104150  1.105916  0.095152 -0.417527  0.292955
#
#           7         8         9        10        11        12        13  \
# 0 -0.009618 -0.339646 -0.262153 -0.184684 -0.519469 -0.454264 -0.019621
# 1 -0.167853 -0.146482  0.101149 -0.341681 -0.039288 -0.374603 -0.341793
# 2  0.417331 -0.384269  0.022868 -0.459438  0.230815 -0.246265 -0.310782
# 3  0.202491 -0.332546 -0.269619 -0.513244 -0.229074 -0.154151 -0.359605
# 4 -0.014235 -0.084466 -0.272330 -0.479036 -0.298965 -0.302943 -0.389424
#
#          14        15        16        17        18        19
# 0 -0.108034 -0.304638 -0.282804 -0.398353 -0.051061 -0.332652
# 1 -0.312271 -0.356083 -0.348068 -0.339773 -0.348472 -0.274032
# 2 -0.176841 -0.030780 -0.071828 -0.169184 -0.250173 -0.114092
# 3 -0.289276 -0.364681 -0.225777 -0.493332 -0.192749 -0.361716
# 4 -0.199455 -0.248873 -0.196090 -0.223494  0.003092 -0.182166

# %% [markdown]
# GMM

# %%
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt


import pandas as pd

mfcc_tsne_PCA_df = pd.read_csv('MFCCtsnePCA_max.csv')
mfcc_df = pd.read_csv('MFCC_max_20.csv')
print(mfcc_tsne_PCA_df.head())

# Filter the rows where 'Song' equals specific values (1, 2, 3, 4, 5, 6)
song_identifiers = ['mfcc_output_16', 'mfcc_output_56', 'mfcc_output_59', 'mfcc_output_40', 'mfcc_output_73','mfcc_output_3']

filtered_points = mfcc_tsne_PCA_df[mfcc_tsne_PCA_df['Song'].isin(song_identifiers)]


song_names = mfcc_tsne_PCA_df['Song']  # Save the 'Song' column
mfcc_tsne_PCA_df = mfcc_tsne_PCA_df.drop(columns=['Song'])  # Use only the MFCC coefficients for PCA and t-SNE



# Display or assign these points as centroids
initial_centroids = filtered_points[['Dimension 1', 'Dimension 2']].values

print("Initial Centroids:")
print(initial_centroids)

mfcc_tsne_PCA_df = mfcc_tsne_PCA_df.drop(mfcc_tsne_PCA_df.columns[0], axis=1)
print(mfcc_tsne_PCA_df.head())

# Assuming mfcc_df is your DataFrame with 115 songs and 20 MFCC coefficients
gmm = GaussianMixture(n_components=6,means_init=initial_centroids, random_state=42)  # Use 6 components based on your categories
gmm_labels = gmm.fit_predict(mfcc_tsne_PCA_df)

gmm_probabilities = gmm.predict_proba(mfcc_tsne_PCA_df)
probability_df = pd.DataFrame(gmm_probabilities, columns=[f'Cluster_{i}' for i in range(6)])

probability_df['Song'] = song_names 
probability_df.to_csv('Max_Probability.csv')

# Add GMM labels to the DataFrame for analysis
mfcc_df['GMM Cluster'] = gmm_labels

# Visualizing GMM clusters (you can use t-SNE/PCA results here too)
plt.figure(figsize=(8, 6))
plt.scatter(mfcc_tsne_PCA_df['Dimension 1'], mfcc_tsne_PCA_df['Dimension 2'], c=gmm_labels, cmap='viridis', edgecolor='k')
plt.title('GMM Clusters on t-SNE Reduced Data')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.colorbar(label='Cluster')
plt.show()

mfcc_tsne_PCA_df['GMM Cluster'] = gmm_labels

mfcc_tsne_PCA_df['Song'] = song_names  # Add the 'Song' column back to the t-SNE results
mfcc_tsne_PCA_df.to_csv('Output_GMM_Max.csv')



# Optional: Print cluster assignment
print(mfcc_df['GMM Cluster'].value_counts())
# Out:
#    Unnamed: 0  Dimension 1  Dimension 2            Song
# 0           0    -0.735229    -0.254079  mfcc_output_49
# 1           1     0.037667     2.958447  mfcc_output_61
# 2           2     2.520885     2.738429  mfcc_output_75
# 3           3    -1.140278     1.238457  mfcc_output_74
# 4           4     1.486148     1.609223  mfcc_output_60
# Initial Centroids:
# [[ 1.3386508  -1.8400106 ]
#  [ 2.5526297  -0.91811883]
#  [-0.64133316  0.9397007 ]
#  [-4.295175    2.429276  ]
#  [ 2.792591    0.30406982]
#  [-1.2004151   0.12354842]]
#    Dimension 1  Dimension 2
# 0    -0.735229    -0.254079
# 1     0.037667     2.958447
# 2     2.520885     2.738429
# 3    -1.140278     1.238457
# 4     1.486148     1.609223
# GMM Cluster
# 2    30
# 1    24
# 5    21
# 4    14
# 0    14
# 3    12
# Name: count, dtype: int64
