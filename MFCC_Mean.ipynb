# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
 

for song_no in range(1,10):
    # Load the MFCC file
    file_path = './MFCC-files-v2/' + '0' + str(song_no) + '-MFCC.csv'  # Update with your file path
    mfcc_data = pd.read_csv(file_path, header=None)  # Assuming the file has no header

    # Calculate the mean for each row (axis=1 computes mean across columns for each row)
    mfcc_mean = mfcc_data.mean(axis=1)

    # Convert the result to a DataFrame with 20 rows and 1 column
    mfcc_mean_df = pd.DataFrame(mfcc_mean)

    # Print the result to verify
    

    scaler = StandardScaler()
    mfcc_mean_standardized = scaler.fit_transform(mfcc_mean_df)

    # Convert back to DataFrame for saving
    mfcc_standardized_df = pd.DataFrame(mfcc_mean_standardized)

    print(mfcc_standardized_df)
    # Optionally, save the result to a new CSV file
    mfcc_standardized_df.to_csv('MFCC_Meaned/mfcc_output_' + str(song_no) +'.csv', index=False, header=False)

    # mfcc_mean_df.to_csv('MFCC_Meaned/mfcc_mean_output' + str(song_no) +'.csv', index=False, header=False)



for song_no in range(10,116):
    # Load the MFCC file
    file_path = './MFCC-files-v2/' + str(song_no) + '-MFCC.csv'  # Update with your file path
    mfcc_data = pd.read_csv(file_path, header=None)  # Assuming the file has no header

    # Calculate the mean for each row (axis=1 computes mean across columns for each row)
    mfcc_mean = mfcc_data.mean(axis=1)

    # Convert the result to a DataFrame with 20 rows and 1 column
    mfcc_mean_df = pd.DataFrame(mfcc_mean)


    scaler = StandardScaler()
    mfcc_mean_standardized = scaler.fit_transform(mfcc_mean_df)

    # Convert back to DataFrame for saving
    mfcc_standardized_df = pd.DataFrame(mfcc_mean_standardized)


    # Print the result to verify
    print(mfcc_standardized_df)

    # Optionally, save the result to a new CSV file
    mfcc_standardized_df.to_csv('MFCC_Meaned/mfcc_output_' + str(song_no) +'.csv', index=False, header=False)



    # mfcc_mean_df.to_csv('MFCC_Meaned/mfcc_mean_output_' + str(song_no) +'.csv', index=False, header=False)
# Out:
#            0
# 0  -3.655639
# 1   2.520397
# 2   0.073735
# 3   0.315705
# 4   0.191052
# 5   0.242521
# 6   0.036160
# 7   0.184731
# 8   0.047712
# 9   0.060935
# 10  0.011142
# 11  0.126033
# 12  0.034415
# 13  0.030298
# 14 -0.017400
# 15 -0.026178
# 16 -0.037460
# 17 -0.132799
# 18 -0.046849
# 19  0.041487
#            0
# 0  -3.662349
# 1   2.382365
# 2  -0.076499
# 3   0.580302
# 4   0.106646
# 5   0.492832
# 6  -0.308152
# 7   0.166977
# 8   0.031337
# 9  -0.123208
# 10 -0.088925
# 11  0.347621
# 12 -0.051950
# 13  0.031547
# 14  0.146490
# 15  0.036144
# 16 -0.092896
# 17  0.085284
# 18  0.045972
# 19 -0.049539
#            0
# 0  -3.248236
# 1   2.789172
# 2  -0.965744
# 3   0.635979
# 4  -0.167667
# 5   0.381831
# 6  -0.220929
# 7   0.238967
# 8   0.029006
# 9   0.107254
# 10  0.035613
# 11  0.143216
# 12  0.043881
# 13  0.042565
# 14  0.070444
# 15 -0.017436
# 16  0.079836
# 17 -0.027525
# 18  0.047566
# 19  0.002209
#            0
# 0  -3.919918
# 1   1.561798
# 2  -0.734734
# 3   0.943612
# 4  -0.105991
# 5   0.533514
# 6  -0.175505
# 7   0.439643
# 8  -0.037288
# 9   0.201687
# 10  0.115403
# 11  0.147291
# 12  0.106692
# 13  0.081430
# 14  0.205437
# 15  0.030209
# 16  0.214053
# 17  0.079473
# 18  0.208755
# 19  0.104440
#            0
# 0  -3.351313
# 1   2.864181
# 2  -0.548596
# 3   0.176352
# 4   0.454637
# 5  -0.041290
# 6   0.072891
# 7   0.046306
# 8   0.008959
# 9   0.033750
# 10 -0.007563
# 11  0.068772
# 12  0.066429
# 13  0.031666
# 14  0.023420
# 15 -0.018122
# 16  0.001863
# 17  0.024848
# 18  0.042951
# 19  0.049860
#            0
# 0  -3.486757
# 1   2.513326
# 2  -0.443324
# 3   0.922016
# 4  -0.297041
# 5   0.272819
# 6  -0.191845
# 7   0.321816
# 8  -0.185731
# 9   0.118383
# 10 -0.079060
# 11 -0.044510
# 12  0.029060
# 13 -0.047261
# 14  0.114686
# 15  0.028077
# 16  0.179773
# 17 -0.064221
# 18  0.233544
# 19  0.106249
#            0
# 0  -3.633070
# 1   2.380264
# 2  -0.773699
# 3   0.568343
# 4   0.213344
# 5   0.079227
# 6   0.183560
# 7   0.203995
# 8   0.075729
# 9   0.119025
# 10  0.121571
# 11  0.130449
# 12 -0.013451
# 13  0.046696
# 14  0.096621
# 15 -0.018824
# 16  0.127741
# 17  0.045378
# 18 -0.016373
# 19  0.063474
#            0
# 0  -3.223116
# 1   2.802001
# 2  -0.594021
# 3   0.909522
# 4  -0.329320
# 5   0.486982
# 6  -0.231115
# 7   0.269886
# 8  -0.145128
# 9   0.217622
# 10 -0.127800
# 11  0.078508
# 12 -0.090183
# 13  0.022236
# 14 -0.078894
# 15 -0.012101
# 16  0.003669
# 17  0.004427
# 18  0.047884
# 19 -0.011059
#            0
# 0  -3.365045
# 1   2.768199
# 2  -0.755785
# 3   0.129879
# 4   0.602051
# 5  -0.102019
# 6   0.004076
# 7   0.140446
# 8   0.027841
# 9   0.040353
# 10  0.015020
# 11  0.014330
# 12  0.067835
# 13  0.046279
# 14  0.045827
# 15  0.083307
# 16  0.063297
# 17  0.053580
# 18  0.067019
# 19  0.053509
#            0
# 0  -3.010358
# 1   3.100617
# 2  -0.216224
# 3   0.284648
# 4  -0.402742
# 5   0.403715
# 6   0.390665
# 7  -0.648277
# 8   0.139859
# 9   0.272782
# 10 -0.316638
# 11 -0.035859
# 12  0.122871
# 13  0.019399
# 14 -0.205827
# 15 -0.033771
# 16  0.145281
# 17 -0.105320
# 18 -0.010924
# 19  0.106105
#            0
# 0  -3.434681
# 1   2.371635
# 2  -0.981968
# 3   1.155437
# 4   0.065812
# 5   0.310972
# 6   0.074338
# 7   0.333630
# 8  -0.151680
# 9   0.027239
# 10  0.089771
# 11  0.031260
# 12 -0.039021
# 13  0.039308
# 14  0.083731
# 15 -0.064330
# 16  0.090166
# 17 -0.053466
# 18 -0.004211
# 19  0.056057
#            0
# 0  -3.756366
# 1   2.149001
# 2  -0.519422
# 3   0.826402
# 4  -0.030036
# 5   0.367102
# 6  -0.124492
# 7   0.313164
# 8   0.000827
# 9   0.081623
# 10  0.026701
# 11  0.112558
# 12  0.009105
# 13  0.057300
# 14  0.099657
# 15  0.028177
# 16  0.096002
# 17  0.046415
# 18  0.126064
# 19  0.090217
#            0
# 0  -3.385785
# 1   2.502825
# 2  -1.027306
# 3   0.988606
# 4  -0.046893
# 5   0.094689
# 6  -0.041884
# 7   0.347622
# 8  -0.067326
# 9   0.001213
# 10  0.160465
# 11 -0.013254
# 12 -0.026621
# 13  0.105429
# 14 -0.037896
# 15  0.047778
# 16  0.172512
# 17 -0.018187
# 18  0.120598
# 19  0.123415
#            0
# 0  -3.417145
# 1   2.397481
# 2  -0.899332
# 3   1.260217
# 4  -0.098013
# 5   0.321861
# 6  -0.050253
# 7   0.150524
# 8  -0.021148
# 9  -0.021229
# 10  0.019496
# 11  0.046258
# 12  0.153286
# 13 -0.033562
# 14  0.071486
# 15  0.060258
# 16  0.009204
# 17  0.033343
# 18  0.038218
# 19 -0.020950
#            0
# 0  -3.427667
# 1   2.547689
# 2  -0.755062
# 3   0.770096
# 4  -0.133284
# 5   0.552987
# 6  -0.228393
# 7   0.341809
# 8  -0.070676
# 9   0.071408
# 10  0.000118
# 11  0.009830
# 12 -0.052791
# 13 -0.059120
# 14  0.143105
# 15 -0.022268
# 16  0.221322
# 17 -0.012815
# 18  0.131478
# 19 -0.027767
#            0
# 0  -3.946663
# 1   1.950801
# 2  -0.145185
# 3   0.599635
# 4   0.176606
# 5   0.331621
# 6   0.017222
# 7   0.147906
# 8   0.103315
# 9   0.062901
# 10  0.034485
# 11  0.135388
# 12  0.075484
# 13  0.057933
# 14  0.067305
# 15  0.050322
# 16  0.015518
# 17  0.092843
# 18  0.097148
# 19  0.075412
#            0
# 0  -3.743908
# 1   2.291720
# 2  -0.002106
# 3   0.626964
# 4   0.144507
# 5   0.446970
# 6  -0.114026
# 7   0.059215
# 8   0.143733
# 9   0.018696
# 10 -0.187792
# 11  0.146545
# 12  0.087543
# 13 -0.049993
# 14  0.022207
# 15  0.102227
# 16 -0.026616
# 17  0.011671
# 18  0.033125
# 19 -0.010681
#            0
# 0  -3.272105
# 1   2.916937
# 2  -0.730811
# 3   0.049709
# 4   0.462630
# 5   0.058954
# 6  -0.031000
# 7   0.079311
# 8   0.023243
# 9   0.001125
# 10  0.008184
# 11  0.055874
# 12  0.075773
# 13  0.043666
# 14  0.043999
# 15  0.029217
# 16  0.037992
# 17  0.051685
# 18  0.065792
# 19  0.029826
#            0
# 0  -3.892542
# 1   1.832443
# 2  -0.728232
# 3   0.767862
# 4   0.213392
# 5   0.264210
# 6   0.019126
# 7   0.329814
# 8  -0.000789
# 9   0.070285
# 10  0.172281
# 11  0.087316
# 12  0.151168
# 13  0.131084
# 14  0.074607
# 15  0.069599
# 16  0.169265
# 17  0.088348
# 18  0.103924
# 19  0.076839
#            0
# 0  -3.755829
# 1   2.089738
# 2  -0.019113
# 3   1.041826
# 4  -0.146305
# 5   0.477952
# 6  -0.138652
# 7   0.296579
# 8  -0.119990
# 9   0.168327
# 10 -0.050625
# 11  0.161839
# 12 -0.068869
# 13  0.016110
# 14 -0.044311
# 15  0.039376
# 16 -0.032199
# 17  0.045714
# 18  0.012753
# 19  0.025680
#            0
# 0  -3.555146
# 1   2.065816
# 2  -1.161030
# 3   1.183064
# 4   0.004571
# 5   0.352516
# 6  -0.086860
# 7   0.365016
# 8   0.064626
# 9   0.021970
# 10  0.021162
# 11  0.144415
# 12  0.135942
# 13  0.111662
# 14  0.108558
# 15  0.060321
# 16  0.027137
# 17  0.066097
# 18  0.015867
# 19  0.054295
#            0
# 0  -3.529750
# 1   2.459699
# 2  -0.640098
# 3   0.956975
# 4  -0.057462
# 5   0.254028
# 6   0.013050
# 7   0.287787
# 8  -0.019177
# 9   0.064562
# 10  0.052488
# 11  0.049485
# 12 -0.026551
# 13  0.009243
# 14  0.013782
# 15  0.029353
# 16  0.039990
# 17 -0.003720
# 18  0.031174
# 19  0.015142
#            0
# 0  -3.375909
# 1   2.831478
# 2  -0.534262
# 3   0.201793
# 4   0.450703
# 5  -0.060593
# 6   0.119714
# 7   0.123729
# 8   0.012293
# 9   0.081607
# 10  0.024808
# 11 -0.013312
# 12 -0.047772
# 13 -0.012544
# 14 -0.015667
# 15 -0.011630
# 16  0.062007
# 17  0.063445
# 18  0.055562
# 19  0.044551
#            0
# 0  -3.700191
# 1   2.370227
# 2  -0.254133
# 3   0.680781
# 4   0.027562
# 5   0.272593
# 6  -0.013036
# 7   0.211363
# 8   0.030817
# 9  -0.015488
# 10  0.063087
# 11  0.076490
# 12  0.131544
# 13  0.018457
# 14  0.021436
# 15  0.064037
# 16 -0.067354
# 17  0.067023
# 18  0.019346
# 19 -0.004561
#            0
# 0  -3.718733
# 1   2.247199
# 2  -0.706044
# 3   0.612938
# 4   0.184951
# 5   0.208807
# 6   0.085400
# 7   0.239123
# 8   0.066951
# 9   0.111486
# 10  0.123141
# 11  0.103190
# 12 -0.043255
# 13  0.016375
# 14  0.063264
# 15  0.012391
# 16  0.186550
# 17  0.019752
# 18  0.054197
# 19  0.132318
#            0
# 0  -3.340191
# 1   2.922823
# 2  -0.172215
# 3  -0.270789
# 4   0.397181
# 5   0.095087
# 6  -0.044949
# 7   0.082566
# 8   0.003249
# 9   0.012239
# 10  0.043802
# 11 -0.038470
# 12 -0.009690
# 13  0.032939
# 14  0.002330
# 15  0.047415
# 16  0.079065
# 17  0.044638
# 18  0.056218
# 19  0.056752
#            0
# 0  -3.921540
# 1   2.023041
# 2   0.230025
# 3   0.553711
# 4   0.273011
# 5   0.163084
# 6   0.133693
# 7   0.107842
# 8   0.118639
# 9   0.031334
# 10  0.009722
# 11  0.087293
# 12  0.003035
# 13  0.049632
# 14 -0.003406
# 15 -0.032534
# 16  0.025646
# 17 -0.003455
# 18  0.087286
# 19  0.063940
#            0
# 0  -3.416978
# 1   2.772671
# 2  -0.480260
# 3  -0.074791
# 4   0.542870
# 5   0.124448
# 6  -0.055187
# 7   0.119512
# 8  -0.042245
# 9  -0.048723
# 10  0.011690
# 11  0.014003
# 12  0.108796
# 13  0.140124
# 14  0.108580
# 15  0.093591
# 16  0.036079
# 17 -0.059389
# 18 -0.001770
# 19  0.106978
#            0
# 0  -3.498919
# 1   2.680021
# 2  -0.337266
# 3  -0.022157
# 4   0.616294
# 5   0.006344
# 6  -0.100102
# 7   0.199768
# 8   0.039020
# 9  -0.033416
# 10  0.086030
# 11  0.030439
# 12  0.030842
# 13  0.092350
# 14  0.019549
# 15 -0.005052
# 16  0.048866
# 17  0.038985
# 18  0.040260
# 19  0.068145
#            0
# 0  -3.684185
# 1   2.332260
# 2  -0.641139
# 3   0.590387
# 4   0.176518
# 5   0.227753
# 6   0.122492
# 7   0.230558
# 8   0.014542
# 9  -0.050205
# 10  0.162549
# 11  0.109175
# 12  0.027681
# 13  0.090623
# 14  0.098842
# 15  0.048862
# 16  0.107248
# 17  0.050919
# 18  0.000380
# 19 -0.015262
#            0
# 0  -3.805432
# 1   2.119603
# 2   0.147661
# 3   0.738592
# 4  -0.238783
# 5   0.468111
# 6  -0.112832
# 7   0.293613
# 8  -0.059224
# 9   0.090012
# 10 -0.103805
# 11  0.106012
# 12 -0.046711
# 13  0.063722
# 14 -0.014958
# 15  0.014288
# 16  0.026380
# 17  0.024350
# 18  0.137337
# 19  0.152064
#            0
# 0  -3.690498
# 1   2.241515
# 2  -0.389033
# 3   0.896397
# 4   0.207989
# 5   0.384518
# 6  -0.017257
# 7   0.395936
# 8  -0.075700
# 9   0.129565
# 10 -0.090101
# 11  0.051445
# 12  0.002333
# 13  0.073758
# 14 -0.057149
# 15  0.051513
# 16 -0.082468
# 17  0.014539
# 18 -0.022651
# 19 -0.024653
#            0
# 0  -3.842836
# 1   1.915480
# 2  -0.696556
# 3   0.879159
# 4   0.194594
# 5   0.102110
# 6  -0.044838
# 7   0.285773
# 8   0.078475
# 9   0.016861
# 10  0.087977
# 11  0.018321
# 12  0.021021
# 13  0.109685
# 14  0.056297
# 15  0.175079
# 16  0.217612
# 17  0.085470
# 18  0.163603
# 19  0.176713
#            0
# 0  -3.867425
# 1   2.108359
# 2  -0.055561
# 3   0.558146
# 4  -0.039790
# 5   0.344912
# 6  -0.138747
# 7   0.209960
# 8  -0.026119
# 9   0.076967
# 10 -0.034228
# 11  0.129639
# 12  0.043829
# 13  0.102847
# 14  0.114288
# 15  0.071447
# 16  0.112284
# 17  0.062303
# 18  0.144077
# 19  0.082812
#            0
# 0  -3.543969
# 1   2.576401
# 2  -0.081692
# 3   0.641336
# 4  -0.111603
# 5   0.407325
# 6  -0.048592
# 7   0.359967
# 8   0.037360
# 9   0.097508
# 10 -0.097455
# 11  0.122586
# 12 -0.104262
# 13 -0.063587
# 14 -0.029196
# 15 -0.117591
# 16  0.030137
# 17 -0.070747
# 18 -0.041998
# 19  0.038072
#            0
# 0  -3.176756
# 1   2.679379
# 2  -1.146269
# 3   1.140375
# 4  -0.010291
# 5   0.149084
# 6   0.086341
# 7   0.166594
# 8   0.101456
# 9   0.029455
# 10  0.016099
# 11 -0.022313
# 12  0.086789
# 13 -0.170968
# 14  0.080371
# 15 -0.004568
# 16 -0.021947
# 17  0.035800
# 18 -0.001395
# 19 -0.017235
#            0
# 0  -3.344659
# 1   2.418852
# 2  -0.944650
# 3   1.309225
# 4   0.066457
# 5   0.471381
# 6  -0.211705
# 7   0.044285
# 8   0.105198
# 9  -0.095727
# 10 -0.125258
# 11  0.085460
# 12  0.126630
# 13 -0.066205
# 14  0.013513
# 15  0.082007
# 16 -0.026074
# 17 -0.009603
# 18 -0.005102
# 19  0.105975
#            0
# 0  -3.570864
# 1   2.644977
# 2  -0.060378
# 3   0.003860
# 4   0.424531
# 5  -0.028475
# 6  -0.031689
# 7   0.130294
# 8  -0.054180
# 9  -0.058058
# 10  0.041705
# 11  0.004565
# 12  0.020496
# 13  0.056428
# 14  0.055031
# 15  0.082449
# 16  0.091718
# 17  0.080752
# 18  0.082750
# 19  0.084087
#            0
# 0  -3.597460
# 1   2.137116
# 2  -0.944609
# 3   1.135905
# 4  -0.034582
# 5   0.273789
# 6  -0.019581
# 7   0.268089
# 8  -0.112971
# 9   0.092879
# 10  0.113037
# 11 -0.040324
# 12 -0.068216
# 13  0.010874
# 14  0.088037
# 15  0.090216
# 16  0.215777
# 17  0.154639
# 18  0.168390
# 19  0.068997
#            0
# 0  -3.504860
# 1   2.551540
# 2  -0.763107
# 3   0.710814
# 4   0.081652
# 5   0.015020
# 6   0.169554
# 7   0.013450
# 8   0.135397
# 9  -0.018727
# 10  0.028150
# 11  0.067692
# 12 -0.051177
# 13  0.019778
# 14  0.046757
# 15  0.086796
# 16  0.133147
# 17  0.100458
# 18  0.118798
# 19  0.058867
#            0
# 0  -3.364417
# 1   2.643876
# 2  -0.678181
# 3   1.028616
# 4  -0.019734
# 5   0.233608
# 6   0.089856
# 7   0.177914
# 8  -0.158290
# 9  -0.028735
# 10  0.025665
# 11 -0.001893
# 12 -0.185911
# 13  0.029342
# 14 -0.002071
# 15  0.013171
# 16  0.100777
# 17 -0.004005
# 18  0.033058
# 19  0.067352
#            0
# 0  -3.634409
# 1   2.461742
# 2  -0.330745
# 3   0.666732
# 4   0.114704
# 5   0.077022
# 6   0.013144
# 7   0.309126
# 8   0.040504
# 9   0.040129
# 10 -0.062453
# 11 -0.011601
# 12 -0.121201
# 13 -0.005518
# 14  0.036275
# 15  0.072946
# 16  0.105402
# 17  0.053215
# 18  0.041345
# 19  0.133641
#            0
# 0  -3.576008
# 1   2.331678
# 2  -0.785076
# 3   0.959187
# 4   0.060939
# 5   0.193157
# 6   0.071200
# 7   0.225535
# 8  -0.068917
# 9  -0.032507
# 10  0.119521
# 11 -0.060221
# 12 -0.082281
# 13  0.123531
# 14  0.159648
# 15  0.096152
# 16  0.222613
# 17  0.092017
# 18  0.009110
# 19 -0.059279
#            0
# 0  -3.629886
# 1   2.264043
# 2  -0.313587
# 3   0.902657
# 4  -0.360744
# 5   0.505040
# 6  -0.326704
# 7   0.372226
# 8  -0.098945
# 9   0.181893
# 10  0.050338
# 11  0.106837
# 12  0.144979
# 13 -0.038927
# 14  0.162800
# 15 -0.050451
# 16  0.167522
# 17 -0.077120
# 18  0.094118
# 19 -0.056090
#            0
# 0  -3.361582
# 1   2.777614
# 2  -0.288028
# 3   0.788690
# 4  -0.126325
# 5   0.353794
# 6  -0.139787
# 7   0.243492
# 8  -0.107756
# 9   0.030880
# 10 -0.100562
# 11  0.101108
# 12 -0.086903
# 13 -0.061060
# 14 -0.004552
# 15 -0.049929
# 16  0.036138
# 17 -0.034930
# 18  0.085632
# 19 -0.055936
#            0
# 0  -3.456515
# 1   2.661716
# 2  -0.771983
# 3   0.439572
# 4   0.356845
# 5   0.088264
# 6   0.086793
# 7   0.049908
# 8   0.058863
# 9   0.032175
# 10  0.008410
# 11  0.097349
# 12  0.075827
# 13  0.042146
# 14  0.036489
# 15  0.001571
# 16  0.037783
# 17  0.055744
# 18  0.072909
# 19  0.026133
#            0
# 0  -3.180155
# 1   2.976037
# 2  -0.671705
# 3   0.525839
# 4  -0.350946
# 5   0.103207
# 6   0.135125
# 7  -0.100020
# 8  -0.072944
# 9   0.080726
# 10  0.010255
# 11  0.003027
# 12 -0.142797
# 13  0.079874
# 14 -0.051781
# 15  0.039601
# 16  0.125634
# 17  0.173121
# 18  0.139091
# 19  0.178813
#            0
# 0  -3.589935
# 1   2.384143
# 2  -0.532551
# 3   0.999544
# 4   0.050064
# 5   0.298472
# 6   0.065458
# 7   0.034218
# 8   0.021400
# 9   0.102302
# 10 -0.111416
# 11  0.052580
# 12  0.011167
# 13  0.093014
# 14  0.087062
# 15  0.008495
# 16 -0.046773
# 17  0.006933
# 18  0.060755
# 19  0.005067
#            0
# 0  -3.427007
# 1   2.349735
# 2  -1.184606
# 3   1.058556
# 4  -0.015709
# 5   0.207848
# 6   0.068949
# 7   0.297018
# 8  -0.075834
# 9   0.036555
# 10  0.108738
# 11  0.041638
# 12 -0.009150
# 13  0.071690
# 14  0.046094
# 15  0.038444
# 16  0.162163
# 17  0.045833
# 18  0.099987
# 19  0.079058
#            0
# 0  -3.388791
# 1   2.804157
# 2  -0.415339
# 3  -0.228635
# 4   0.554727
# 5   0.211523
# 6   0.001492
# 7   0.144528
# 8   0.017533
# 9  -0.098923
# 10 -0.056206
# 11 -0.024903
# 12  0.041502
# 13  0.102177
# 14  0.022352
# 15  0.049708
# 16  0.120837
# 17  0.099974
# 18  0.030255
# 19  0.012032
#            0
# 0  -3.226489
# 1   2.753075
# 2  -1.012742
# 3   0.755847
# 4   0.499246
# 5  -0.187721
# 6   0.254593
# 7  -0.091137
# 8   0.055020
# 9   0.099913
# 10 -0.125707
# 11  0.099044
# 12 -0.020317
# 13 -0.016425
# 14  0.091884
# 15 -0.030611
# 16  0.055615
# 17  0.009365
# 18 -0.021313
# 19  0.058861
#            0
# 0  -3.675142
# 1   2.256064
# 2  -0.906895
# 3   0.477094
# 4  -0.029049
# 5   0.299318
# 6  -0.057195
# 7   0.273431
# 8   0.014442
# 9   0.171114
# 10  0.087188
# 11  0.104770
# 12  0.098609
# 13  0.087463
# 14  0.166518
# 15  0.110150
# 16  0.198709
# 17  0.051932
# 18  0.153386
# 19  0.118093
#            0
# 0  -2.941453
# 1   2.915089
# 2  -0.316076
# 3   1.207416
# 4  -0.400077
# 5   0.742156
# 6  -0.352829
# 7   0.408097
# 8  -0.258523
# 9   0.102306
# 10 -0.198679
# 11 -0.032837
# 12 -0.294864
# 13 -0.123193
# 14 -0.028636
# 15 -0.135544
# 16  0.044076
# 17 -0.147889
# 18 -0.024586
# 19 -0.163955
#            0
# 0  -3.538234
# 1   2.390680
# 2  -0.735434
# 3   1.036061
# 4   0.024822
# 5   0.306225
# 6  -0.002285
# 7   0.191523
# 8   0.021375
# 9   0.048301
# 10 -0.006174
# 11  0.067512
# 12  0.049630
# 13 -0.026863
# 14  0.037094
# 15 -0.015721
# 16  0.008839
# 17  0.020154
# 18  0.062679
# 19  0.059817
#            0
# 0  -3.525300
# 1   2.582918
# 2  -0.294213
# 3   0.801232
# 4  -0.014130
# 5   0.265212
# 6  -0.025578
# 7   0.211668
# 8  -0.096980
# 9   0.025197
# 10 -0.120076
# 11  0.013493
# 12  0.110316
# 13  0.042616
# 14  0.101814
# 15  0.017535
# 16 -0.017025
# 17  0.024886
# 18 -0.033172
# 19 -0.070414
#            0
# 0  -3.377854
# 1   2.658910
# 2  -0.901709
# 3   0.713414
# 4   0.263779
# 5   0.153101
# 6   0.020035
# 7   0.229549
# 8   0.047031
# 9   0.059600
# 10  0.119675
# 11 -0.009291
# 12 -0.042224
# 13  0.007237
# 14 -0.074802
# 15  0.068870
# 16  0.099928
# 17 -0.090917
# 18  0.029249
# 19  0.026419
#            0
# 0  -3.429759
# 1   2.605912
# 2  -0.486817
# 3   1.005151
# 4   0.164199
# 5   0.284347
# 6  -0.077841
# 7   0.064523
# 8   0.143653
# 9   0.018511
# 10 -0.186292
# 11  0.045339
# 12 -0.069028
# 13 -0.022864
# 14  0.030932
# 15 -0.039517
# 16 -0.094658
# 17 -0.007684
# 18  0.074476
# 19 -0.022583
#            0
# 0  -3.454437
# 1   2.460130
# 2  -0.724844
# 3   1.127794
# 4   0.042323
# 5   0.333954
# 6  -0.101116
# 7   0.188989
# 8   0.054396
# 9   0.051606
# 10 -0.040250
# 11  0.091560
# 12  0.067371
# 13 -0.007497
# 14  0.092884
# 15 -0.017798
# 16 -0.128090
# 17  0.041245
# 18  0.022994
# 19 -0.101216
#            0
# 0  -3.068153
# 1   2.822522
# 2  -1.329513
# 3   0.814314
# 4   0.147774
# 5  -0.024252
# 6   0.315457
# 7  -0.132759
# 8   0.127192
# 9  -0.019519
# 10  0.007963
# 11  0.096268
# 12 -0.036709
# 13  0.096393
# 14 -0.005279
# 15  0.007137
# 16  0.073385
# 17 -0.012021
# 18  0.070352
# 19  0.049449
#            0
# 0  -2.705273
# 1   3.057968
# 2  -1.522246
# 3   0.910526
# 4  -0.019800
# 5  -0.108802
# 6   0.315724
# 7  -0.119290
# 8   0.123129
# 9  -0.007803
# 10 -0.063494
# 11  0.092773
# 12 -0.105924
# 13 -0.015123
# 14  0.022395
# 15 -0.071211
# 16  0.067269
# 17  0.023005
# 18  0.063911
# 19  0.062265
#            0
# 0  -3.508601
# 1   2.664207
# 2   0.466973
# 3   0.292804
# 4   0.013578
# 5   0.460714
# 6  -0.076267
# 7  -0.006739
# 8   0.060016
# 9   0.093084
# 10 -0.077382
# 11  0.066657
# 12 -0.107395
# 13  0.017324
# 14 -0.033638
# 15 -0.057941
# 16 -0.125489
# 17 -0.067337
# 18 -0.098667
# 19  0.024100
#            0
# 0  -3.669699
# 1   2.348992
# 2  -0.498373
# 3   0.744715
# 4   0.095460
# 5   0.251493
# 6   0.023838
# 7   0.318055
# 8   0.025460
# 9   0.111464
# 10  0.035401
# 11  0.013744
# 12 -0.025324
# 13 -0.024284
# 14 -0.021134
# 15  0.004254
# 16  0.056438
# 17  0.035204
# 18  0.050673
# 19  0.123623
#            0
# 0  -3.374365
# 1   2.865676
# 2  -0.380147
# 3   0.219230
# 4   0.443241
# 5   0.040624
# 6   0.063640
# 7  -0.012266
# 8   0.012522
# 9   0.064242
# 10 -0.022873
# 11 -0.014507
# 12  0.015335
# 13  0.009666
# 14  0.018063
# 15 -0.001345
# 16  0.000433
# 17  0.017549
# 18  0.023607
# 19  0.011675
#            0
# 0  -3.663921
# 1   2.216677
# 2  -0.785871
# 3   0.857231
# 4   0.061639
# 5   0.161671
# 6  -0.030943
# 7   0.309022
# 8  -0.092281
# 9   0.149319
# 10  0.101846
# 11 -0.011279
# 12  0.027454
# 13 -0.012494
# 14  0.054391
# 15 -0.050226
# 16  0.201250
# 17  0.089382
# 18  0.209480
# 19  0.207655
#            0
# 0  -3.727767
# 1   2.139070
# 2  -0.727082
# 3   0.848114
# 4   0.259760
# 5   0.259073
# 6  -0.082739
# 7   0.224564
# 8   0.088134
# 9   0.073644
# 10  0.016923
# 11  0.109121
# 12  0.119866
# 13  0.062449
# 14  0.141142
# 15 -0.033067
# 16  0.037022
# 17  0.127767
# 18  0.076200
# 19 -0.012195
#            0
# 0  -3.353311
# 1   2.843461
# 2  -0.593687
# 3  -0.047112
# 4   0.502237
# 5  -0.034731
# 6   0.101277
# 7   0.169955
# 8  -0.022499
# 9   0.060754
# 10  0.074496
# 11  0.035223
# 12  0.058200
# 13  0.040869
# 14  0.053766
# 15  0.038210
# 16  0.012989
# 17  0.043493
# 18  0.017332
# 19 -0.000923
#            0
# 0  -3.663371
# 1   2.518483
# 2  -0.218504
# 3   0.059012
# 4   0.312020
# 5   0.087952
# 6  -0.027185
# 7   0.075883
# 8   0.055572
# 9   0.057103
# 10 -0.022416
# 11  0.099349
# 12  0.107078
# 13  0.080313
# 14  0.077625
# 15  0.100040
# 16  0.087833
# 17  0.091002
# 18  0.061760
# 19  0.060451
#            0
# 0  -3.587196
# 1   2.378780
# 2  -0.651579
# 3   0.931945
# 4   0.008091
# 5   0.306583
# 6   0.011348
# 7   0.251634
# 8  -0.011720
# 9   0.038322
# 10  0.054881
# 11  0.105894
# 12  0.029735
# 13  0.038278
# 14  0.041738
# 15 -0.024264
# 16 -0.001138
# 17  0.037976
# 18  0.025829
# 19  0.014862
#            0
# 0  -3.250266
# 1   2.420231
# 2  -0.174576
# 3   1.397532
# 4  -0.560425
# 5   0.807273
# 6  -0.337691
# 7   0.379109
# 8  -0.343737
# 9   0.186300
# 10 -0.264654
# 11  0.082351
# 12 -0.171004
# 13 -0.032288
# 14  0.033327
# 15 -0.117062
# 16  0.108887
# 17 -0.125399
# 18  0.165533
# 19 -0.203441
#            0
# 0  -3.826665
# 1   1.990496
# 2  -0.740262
# 3   0.698691
# 4   0.142932
# 5   0.305669
# 6   0.094099
# 7   0.271371
# 8  -0.019089
# 9   0.126530
# 10  0.051606
# 11  0.033575
# 12  0.009534
# 13  0.019857
# 14  0.105640
# 15  0.085994
# 16  0.172127
# 17  0.069812
# 18  0.254400
# 19  0.153684
#            0
# 0  -3.220981
# 1   2.933984
# 2  -0.754129
# 3   0.542019
# 4   0.165357
# 5  -0.145355
# 6   0.148941
# 7   0.052653
# 8  -0.125410
# 9   0.172063
# 10 -0.037190
# 11 -0.083687
# 12  0.115040
# 13  0.025856
# 14  0.049678
# 15 -0.026956
# 16  0.072657
# 17  0.024126
# 18  0.034580
# 19  0.056755
#            0
# 0  -3.545434
# 1   2.369099
# 2  -0.753854
# 3   0.958724
# 4   0.142677
# 5   0.193494
# 6  -0.102362
# 7   0.382596
# 8  -0.179334
# 9  -0.025329
# 10  0.059489
# 11 -0.067363
# 12 -0.031717
# 13 -0.000398
# 14  0.074106
# 15  0.052289
# 16  0.129462
# 17  0.055430
# 18  0.101647
# 19  0.186778
#            0
# 0  -3.775704
# 1   1.967010
# 2  -0.924461
# 3   0.745461
# 4   0.000368
# 5   0.202535
# 6  -0.055812
# 7   0.352678
# 8  -0.090013
# 9   0.182246
# 10  0.183488
# 11 -0.012145
# 12  0.108509
# 13  0.061742
# 14  0.113278
# 15  0.105458
# 16  0.273964
# 17  0.159944
# 18  0.191207
# 19  0.210248
#            0
# 0  -3.872752
# 1   1.957304
# 2  -0.459171
# 3   0.609565
# 4  -0.039839
# 5   0.402268
# 6  -0.214040
# 7   0.356253
# 8  -0.054668
# 9   0.274101
# 10 -0.009197
# 11  0.219248
# 12  0.028134
# 13  0.115207
# 14  0.138394
# 15  0.056767
# 16  0.190979
# 17  0.007387
# 18  0.216781
# 19  0.077279
#            0
# 0  -3.843477
# 1   2.080526
# 2   0.090905
# 3   0.733616
# 4  -0.113412
# 5   0.423708
# 6   0.012670
# 7   0.217963
# 8  -0.057771
# 9   0.040981
# 10 -0.115354
# 11  0.258788
# 12  0.056775
# 13 -0.014303
# 14 -0.020588
# 15  0.057950
# 16  0.137695
# 17  0.017378
# 18  0.008941
# 19  0.027008
#            0
# 0  -3.396501
# 1   2.582946
# 2  -0.943773
# 3   0.845661
# 4   0.036912
# 5   0.136399
# 6   0.080598
# 7   0.321889
# 8  -0.104552
# 9   0.032220
# 10  0.141852
# 11  0.040389
# 12  0.046600
# 13 -0.035819
# 14  0.028652
# 15 -0.024958
# 16  0.004054
# 17  0.114116
# 18  0.057352
# 19  0.035964
#            0
# 0  -3.534974
# 1   2.384407
# 2  -0.871553
# 3   0.908178
# 4   0.166996
# 5   0.145702
# 6   0.024522
# 7   0.301744
# 8  -0.153602
# 9   0.038701
# 10  0.170744
# 11 -0.027014
# 12 -0.021945
# 13  0.101588
# 14  0.098864
# 15  0.062875
# 16  0.100857
# 17  0.041737
# 18  0.036200
# 19  0.025971
#            0
# 0  -3.358528
# 1   2.586649
# 2  -0.890613
# 3   1.005025
# 4  -0.172044
# 5   0.380433
# 6  -0.048906
# 7   0.105761
# 8   0.112932
# 9   0.053791
# 10  0.049152
# 11  0.032883
# 12 -0.017578
# 13 -0.024814
# 14  0.045500
# 15 -0.003218
# 16  0.062069
# 17 -0.013032
# 18  0.109412
# 19 -0.014872
#            0
# 0  -3.672517
# 1   2.033849
# 2  -0.997483
# 3   1.071019
# 4  -0.002988
# 5   0.097605
# 6   0.199722
# 7   0.113646
# 8   0.109084
# 9  -0.035410
# 10  0.108106
# 11  0.095151
# 12 -0.042997
# 13  0.128597
# 14  0.169600
# 15  0.151312
# 16  0.129844
# 17  0.097708
# 18  0.197375
# 19  0.048778
#            0
# 0  -2.963899
# 1   3.123275
# 2  -0.974552
# 3   0.350769
# 4   0.536860
# 5  -0.172276
# 6   0.207812
# 7   0.065968
# 8  -0.087552
# 9   0.029192
# 10 -0.080049
# 11 -0.000659
# 12 -0.027799
# 13 -0.038885
# 14  0.064696
# 15  0.011158
# 16 -0.021373
# 17 -0.003230
# 18 -0.004635
# 19 -0.014822
#            0
# 0  -3.201873
# 1   2.875154
# 2  -0.595753
# 3   0.609161
# 4   0.364769
# 5   0.547827
# 6  -0.348477
# 7   0.048760
# 8  -0.012244
# 9   0.080118
# 10 -0.348288
# 11 -0.006668
# 12  0.136041
# 13 -0.025508
# 14 -0.151220
# 15  0.058055
# 16  0.072857
# 17 -0.118114
# 18 -0.046266
# 19  0.061667
#            0
# 0  -3.338070
# 1   2.746549
# 2  -0.900756
# 3   0.229686
# 4   0.594858
# 5  -0.127809
# 6   0.134861
# 7   0.147149
# 8  -0.056259
# 9   0.058359
# 10  0.014804
# 11  0.046147
# 12  0.072621
# 13  0.019269
# 14  0.058372
# 15  0.038969
# 16  0.029595
# 17  0.048971
# 18  0.082456
# 19  0.100227
#            0
# 0  -3.503021
# 1   2.645600
# 2  -0.383659
# 3   0.193358
# 4   0.715141
# 5   0.050329
# 6  -0.057703
# 7   0.128440
# 8  -0.005078
# 9  -0.024786
# 10  0.054636
# 11  0.048572
# 12  0.009345
# 13  0.019886
# 14  0.015035
# 15  0.017033
# 16 -0.010491
# 17  0.040325
# 18  0.050442
# 19 -0.003402
#            0
# 0  -3.155502
# 1   2.939730
# 2  -0.905745
# 3   0.459665
# 4   0.549381
# 5  -0.185319
# 6   0.117299
# 7   0.011529
# 8  -0.006252
# 9   0.055382
# 10 -0.074689
# 11  0.023196
# 12  0.022641
# 13 -0.021752
# 14  0.039477
# 15 -0.007278
# 16  0.010403
# 17  0.074474
# 18  0.035999
# 19  0.017361
#            0
# 0  -3.533293
# 1   2.269985
# 2  -0.960912
# 3   1.099698
# 4   0.012675
# 5   0.242444
# 6  -0.103050
# 7   0.229898
# 8   0.037826
# 9   0.006521
# 10  0.057448
# 11  0.002455
# 12  0.001557
# 13  0.089147
# 14  0.010237
# 15 -0.004846
# 16  0.200651
# 17  0.024514
# 18  0.114161
# 19  0.202885
#            0
# 0  -2.653534
# 1   3.302819
# 2  -0.628939
# 3   0.937626
# 4  -0.563482
# 5   0.474364
# 6  -0.306956
# 7   0.191943
# 8  -0.221491
# 9   0.029884
# 10 -0.112406
# 11  0.013255
# 12 -0.069725
# 13 -0.067024
# 14 -0.018115
# 15 -0.111340
# 16 -0.000127
# 17 -0.076374
# 18 -0.015931
# 19 -0.104447
#            0
# 0  -3.691565
# 1   2.275986
# 2  -0.176922
# 3   0.741019
# 4  -0.143490
# 5   0.409614
# 6  -0.281038
# 7   0.447414
# 8  -0.047853
# 9   0.149882
# 10  0.131042
# 11  0.211046
# 12 -0.171103
# 13  0.124253
# 14 -0.065642
# 15 -0.025419
# 16  0.039487
# 17  0.035800
# 18 -0.029253
# 19  0.066742
#            0
# 0  -3.652077
# 1   2.365876
# 2  -0.454584
# 3   0.791132
# 4   0.028586
# 5   0.351726
# 6  -0.046306
# 7   0.176828
# 8  -0.088718
# 9   0.082366
# 10 -0.060830
# 11  0.087446
# 12  0.048207
# 13  0.050503
# 14  0.108090
# 15  0.029322
# 16 -0.006910
# 17  0.121512
# 18  0.117443
# 19 -0.049613
#            0
# 0  -3.040999
# 1   2.920213
# 2  -1.106861
# 3   0.885969
# 4  -0.079325
# 5   0.146109
# 6   0.015462
# 7   0.305772
# 8  -0.267563
# 9   0.048281
# 10  0.093434
# 11 -0.017281
# 12  0.067346
# 13  0.005781
# 14  0.030419
# 15 -0.026555
# 16  0.002494
# 17 -0.039668
# 18  0.007616
# 19  0.049357
#            0
# 0  -3.480932
# 1   2.652635
# 2  -0.044247
# 3   0.618774
# 4   0.032319
# 5   0.489112
# 6  -0.259233
# 7   0.171482
# 8   0.141563
# 9  -0.186235
# 10 -0.176248
# 11  0.159988
# 12 -0.065996
# 13 -0.049678
# 14  0.042797
# 15 -0.051994
# 16 -0.025626
# 17  0.016611
# 18  0.031239
# 19 -0.016330
#            0
# 0  -3.561989
# 1   2.391972
# 2  -0.721581
# 3   0.950383
# 4   0.076531
# 5   0.116798
# 6   0.100486
# 7   0.252137
# 8  -0.113380
# 9   0.091053
# 10  0.078953
# 11 -0.015935
# 12 -0.011430
# 13  0.000201
# 14 -0.001550
# 15  0.025172
# 16  0.100876
# 17 -0.019746
# 18  0.147633
# 19  0.113415
#            0
# 0  -3.338227
# 1   2.688736
# 2  -1.014052
# 3   0.576038
# 4   0.085811
# 5   0.084902
# 6  -0.060939
# 7   0.338765
# 8   0.083076
# 9  -0.021262
# 10  0.109848
# 11  0.001167
# 12  0.113108
# 13  0.050867
# 14  0.101383
# 15  0.032862
# 16 -0.148873
# 17  0.170780
# 18  0.186191
# 19 -0.040181
#            0
# 0  -3.534568
# 1   2.588202
# 2  -0.503488
# 3   0.623282
# 4   0.282128
# 5  -0.075004
# 6   0.226491
# 7  -0.016894
# 8   0.079525
# 9   0.060531
# 10 -0.022050
# 11  0.085573
# 12  0.012994
# 13  0.003510
# 14  0.032806
# 15 -0.020866
# 16  0.007494
# 17  0.058724
# 18  0.051871
# 19  0.059742
#            0
# 0  -3.792984
# 1   2.211015
# 2  -0.432079
# 3   0.542073
# 4   0.292800
# 5   0.122274
# 6   0.100788
# 7   0.175144
# 8   0.083947
# 9   0.058887
# 10  0.087811
# 11  0.064328
# 12 -0.083307
# 13  0.006516
# 14  0.055438
# 15  0.027865
# 16  0.113108
# 17  0.039533
# 18  0.134535
# 19  0.192308
#            0
# 0  -3.511753
# 1   2.567941
# 2  -0.272949
# 3   0.645954
# 4   0.054987
# 5   0.458828
# 6  -0.091669
# 7   0.447149
# 8  -0.226479
# 9   0.166235
# 10 -0.085491
# 11  0.115480
# 12 -0.218244
# 13  0.052470
# 14 -0.030930
# 15 -0.079505
# 16  0.022744
# 17 -0.021626
# 18 -0.022800
# 19  0.029656
#            0
# 0  -3.369645
# 1   2.842111
# 2  -0.499331
# 3  -0.147952
# 4   0.487446
# 5  -0.030651
# 6  -0.068979
# 7   0.121969
# 8   0.034661
# 9   0.030284
# 10  0.070616
# 11  0.056184
# 12  0.052941
# 13  0.054108
# 14  0.058193
# 15  0.065380
# 16  0.066405
# 17  0.064666
# 18  0.059610
# 19  0.051986
#            0
# 0  -3.193838
# 1   3.039326
# 2  -0.589668
# 3  -0.112266
# 4   0.414412
# 5   0.037723
# 6   0.019407
# 7   0.113397
# 8   0.009716
# 9   0.006875
# 10 -0.010620
# 11  0.014595
# 12  0.066123
# 13  0.014625
# 14 -0.011578
# 15 -0.002704
# 16  0.023547
# 17  0.065605
# 18  0.064841
# 19  0.030481
#            0
# 0  -2.956884
# 1   2.774638
# 2  -0.153046
# 3   1.490939
# 4  -0.701042
# 5   0.633345
# 6  -0.084326
# 7   0.100962
# 8  -0.150715
# 9  -0.082388
# 10  0.056781
# 11 -0.278823
# 12  0.141640
# 13 -0.378397
# 14  0.106663
# 15 -0.246284
# 16 -0.056450
# 17 -0.070558
# 18 -0.209822
# 19  0.063768
#            0
# 0  -3.486541
# 1   2.279782
# 2  -1.023765
# 3   1.147913
# 4   0.034861
# 5   0.252153
# 6   0.232720
# 7   0.082563
# 8  -0.188207
# 9   0.147865
# 10  0.056308
# 11 -0.109797
# 12 -0.081863
# 13  0.043004
# 14  0.058873
# 15  0.108161
# 16  0.176075
# 17  0.069419
# 18  0.138386
# 19  0.062090
#            0
# 0  -3.416838
# 1   2.697511
# 2  -0.700655
# 3  -0.052884
# 4   0.673370
# 5  -0.010549
# 6  -0.125070
# 7   0.178523
# 8   0.083763
# 9   0.007972
# 10  0.053059
# 11  0.103006
# 12  0.066927
# 13  0.056008
# 14  0.060634
# 15  0.068522
# 16  0.077379
# 17  0.077208
# 18  0.061726
# 19  0.040388
#            0
# 0  -3.521106
# 1   2.521957
# 2  -0.842103
# 3   0.583079
# 4   0.214959
# 5   0.059138
# 6   0.183072
# 7   0.193614
# 8   0.065793
# 9   0.106396
# 10  0.112085
# 11  0.120889
# 12 -0.034087
# 13  0.031686
# 14  0.083079
# 15 -0.038031
# 16  0.116499
# 17  0.030578
# 18 -0.037297
# 19  0.049800
#            0
# 0  -3.698296
# 1   2.301793
# 2  -0.658630
# 3   0.471214
# 4   0.433456
# 5  -0.083390
# 6   0.278885
# 7   0.080951
# 8   0.001689
# 9   0.093365
# 10  0.036752
# 11  0.098383
# 12  0.017761
# 13  0.012692
# 14  0.091400
# 15  0.051544
# 16  0.121571
# 17  0.159172
# 18  0.093275
# 19  0.096412
#            0
# 0  -3.757278
# 1   2.176434
# 2  -0.195349
# 3   0.849659
# 4  -0.119875
# 5   0.493383
# 6  -0.102074
# 7   0.222124
# 8   0.035396
# 9   0.179761
# 10 -0.057625
# 11  0.126927
# 12  0.003777
# 13 -0.009987
# 14  0.073184
# 15 -0.002212
# 16  0.050320
# 17 -0.024144
# 18  0.079375
# 19 -0.021796
#            0
# 0  -3.399185
# 1   2.735431
# 2  -0.288799
# 3   0.841373
# 4  -0.026201
# 5   0.225266
# 6  -0.155594
# 7   0.264448
# 8  -0.132447
# 9  -0.022011
# 10  0.002275
# 11 -0.026295
# 12  0.001624
# 13  0.039857
# 14 -0.002672
# 15 -0.067272
# 16  0.012616
# 17 -0.025827
# 18  0.019597
# 19  0.003817
#            0
# 0  -3.803514
# 1   2.266685
# 2  -0.180696
# 3   0.209109
# 4   0.431100
# 5   0.049005
# 6   0.140777
# 7   0.062609
# 8  -0.042626
# 9   0.089656
# 10  0.062079
# 11 -0.035087
# 12 -0.008934
# 13  0.051618
# 14  0.068022
# 15  0.090541
# 16  0.137596
# 17  0.126515
# 18  0.122290
# 19  0.163257
#            0
# 0  -3.563961
# 1   2.601065
# 2  -0.231326
# 3   0.576409
# 4  -0.064679
# 5   0.195381
# 6  -0.042826
# 7   0.230468
# 8  -0.010853
# 9  -0.049757
# 10  0.030420
# 11 -0.049860
# 12 -0.025494
# 13 -0.050208
# 14  0.082661
# 15  0.028375
# 16  0.065741
# 17  0.051190
# 18  0.114128
# 19  0.113126
#            0
# 0  -3.756057
# 1   2.231787
# 2   0.158010
# 3   0.739330
# 4   0.071491
# 5   0.336208
# 6  -0.129298
# 7   0.231739
# 8  -0.156647
# 9   0.087776
# 10 -0.109592
# 11  0.237585
# 12  0.021511
# 13  0.175894
# 14 -0.023104
# 15  0.003586
# 16 -0.095428
# 17 -0.067370
# 18  0.064964
# 19 -0.022385
#            0
# 0  -3.700653
# 1   2.319283
# 2   0.168789
# 3   0.759345
# 4   0.011345
# 5   0.461243
# 6  -0.025087
# 7   0.203004
# 8  -0.071750
# 9   0.112094
# 10 -0.079364
# 11  0.127313
# 12 -0.096413
# 13 -0.037792
# 14 -0.087007
# 15 -0.042032
# 16 -0.044877
# 17 -0.001110
# 18  0.054903
# 19 -0.031233
#            0
# 0  -3.716339
# 1   2.218156
# 2  -0.606360
# 3   0.821427
# 4   0.129555
# 5   0.235787
# 6   0.022784
# 7   0.179882
# 8   0.012196
# 9   0.122088
# 10 -0.001810
# 11  0.156680
# 12 -0.076434
# 13  0.046737
# 14  0.108189
# 15 -0.051427
# 16  0.122580
# 17 -0.016930
# 18  0.128639
# 19  0.164601
#            0
# 0  -3.313092
# 1   2.612509
# 2  -1.250041
# 3   0.711922
# 4   0.168521
# 5   0.055555
# 6   0.156373
# 7   0.095502
# 8   0.049223
# 9   0.074940
# 10  0.006887
# 11  0.105017
# 12  0.047553
# 13  0.009066
# 14  0.127349
# 15  0.057910
# 16  0.088560
# 17  0.090895
# 18  0.075521
# 19  0.029828
#            0
# 0  -3.411559
# 1   2.772928
# 2  -0.500153
# 3  -0.207263
# 4   0.552912
# 5   0.070093
# 6  -0.015131
# 7   0.191581
# 8   0.030055
# 9  -0.007537
# 10  0.090913
# 11  0.046628
# 12  0.035691
# 13  0.070104
# 14  0.040169
# 15  0.041630
# 16  0.061916
# 17  0.036875
# 18  0.037383
# 19  0.062766
#            0
# 0  -3.307698
# 1   2.484726
# 2  -0.969670
# 3   1.316917
# 4  -0.077141
# 5   0.230229
# 6   0.071020
# 7   0.127056
# 8  -0.114784
# 9   0.064655
# 10 -0.075782
# 11 -0.057557
# 12 -0.122875
# 13  0.163047
# 14 -0.101004
# 15  0.007818
# 16  0.089793
# 17 -0.018545
# 18  0.114570
# 19  0.175227
#            0
# 0  -3.394327
# 1   2.452846
# 2  -0.790103
# 3   1.193085
# 4  -0.216761
# 5   0.297907
# 6  -0.195947
# 7   0.345751
# 8  -0.181540
# 9   0.160651
# 10 -0.132482
# 11  0.072164
# 12  0.106252
# 13 -0.034848
# 14  0.029928
# 15  0.015867
# 16  0.003780
# 17  0.105742
# 18  0.105535
# 19  0.056499
#            0
# 0  -3.354838
# 1   2.773159
# 2   0.179352
# 3   0.847054
# 4  -0.235734
# 5   0.348895
# 6  -0.200535
# 7   0.146105
# 8  -0.041967
# 9   0.001517
# 10 -0.113503
# 11  0.087646
# 12 -0.090155
# 13 -0.074302
# 14  0.024598
# 15 -0.121869
# 16 -0.006601
# 17 -0.080049
# 18  0.001956
# 19 -0.090730
#            0
# 0  -3.727390
# 1   2.392037
# 2  -0.249310
# 3   0.425327
# 4   0.192224
# 5   0.166332
# 6   0.014361
# 7   0.088889
# 8   0.027679
# 9  -0.046644
# 10  0.045120
# 11  0.030116
# 12  0.020787
# 13  0.036296
# 14  0.086325
# 15  0.053609
# 16  0.097462
# 17  0.085290
# 18  0.127849
# 19  0.133642

# %% [markdown]
# MFCC Combiner here

# %%
import os
import pandas as pd

# Path to the folder containing the 115 MFCC CSV files
folder_path = './MFCC_Meaned'  # Update with your folder path

# Initialize an empty list to store data from all songs
mfcc_data_list = []
file_names = []  # List to store the file names

# Loop over all files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Read the MFCC file
        file_path = os.path.join(folder_path, file_name)
        mfcc_data = pd.read_csv(file_path, header=None)
        
        # Append the MFCC coefficients as a row in the list
        mfcc_data_list.append(mfcc_data[0].values)
        
        # Store the file name (without .csv) to keep track of which song it is
        file_names.append(file_name.replace('.csv', ''))

# Convert list to DataFrame (115 rows, 20 columns)
mfcc_df = pd.DataFrame(mfcc_data_list)

mfcc_df.to_csv('MFCC_Meaned_20.csv', index=False)


# Add file names as an additional column for tracking
mfcc_df['Song'] = file_names

# Save to a new CSV file with song names
mfcc_df.to_csv('MFCC_Meaned_20_with_Song_Names.csv', index=False)

print(f"Data shape: {mfcc_df.shape}")
# Out:
# Data shape: (115, 21)

# %% [markdown]
# PCA and tsne

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt



import pandas as pd

mfcc_df = pd.read_csv('MFCC_Meaned_20_with_Song_Names.csv')

song_names = mfcc_df['Song']  # Save the 'Song' column
mfcc_df = mfcc_df.drop(columns=['Song'])  # Use only the MFCC coefficients for PCA and t-SNE
print(mfcc_df.head())

# Step 1: Apply PCA to reduce dimensionality to, say, 10 components


pca = PCA(n_components=10)
mfcc_pca = pca.fit_transform(mfcc_df)


# Step 2: Apply t-SNE on the reduced data from PCA
tsne = TSNE(n_components=2, perplexity=45, random_state=69)
mfcc_tsne_pca = tsne.fit_transform(mfcc_pca)

# Convert t-SNE result to a DataFrame for easy handling
mfcc_tsne_pca_df = pd.DataFrame(mfcc_tsne_pca, columns=['Dimension 1', 'Dimension 2'])


# Plot the results of t-SNE after PCA
plt.figure(figsize=(8, 6))
plt.scatter(mfcc_tsne_pca_df['Dimension 1'], mfcc_tsne_pca_df['Dimension 2'], c='blue', edgecolor='k')
plt.title('t-SNE after PCA on 115 Songs MFCCs')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

mfcc_tsne_pca_df['Song'] = song_names  # Add the 'Song' column back to the t-SNE results

mfcc_tsne_pca_df.to_csv('MFCCtsnePCA_Mean.csv')
# Out:
#           0         1         2         3         4         5         6  \
# 0 -3.427007  2.349735 -1.184606  1.058556 -0.015709  0.207848  0.068949
# 1 -3.508601  2.664207  0.466973  0.292804  0.013578  0.460714 -0.076267
# 2 -3.843477  2.080526  0.090905  0.733616 -0.113412  0.423708  0.012670
# 3 -3.872752  1.957304 -0.459171  0.609565 -0.039839  0.402268 -0.214040
# 4 -2.705273  3.057968 -1.522246  0.910526 -0.019800 -0.108802  0.315724
#
#           7         8         9        10        11        12        13  \
# 0  0.297018 -0.075834  0.036555  0.108738  0.041638 -0.009150  0.071690
# 1 -0.006739  0.060016  0.093084 -0.077382  0.066657 -0.107395  0.017324
# 2  0.217963 -0.057771  0.040981 -0.115354  0.258788  0.056775 -0.014303
# 3  0.356253 -0.054668  0.274101 -0.009197  0.219248  0.028134  0.115207
# 4 -0.119290  0.123129 -0.007803 -0.063494  0.092773 -0.105924 -0.015123
#
#          14        15        16        17        18        19
# 0  0.046094  0.038444  0.162163  0.045833  0.099987  0.079058
# 1 -0.033638 -0.057941 -0.125489 -0.067337 -0.098667  0.024100
# 2 -0.020588  0.057950  0.137695  0.017378  0.008941  0.027008
# 3  0.138394  0.056767  0.190979  0.007387  0.216781  0.077279
# 4  0.022395 -0.071211  0.067269  0.023005  0.063911  0.062265

# %% [markdown]
# K Means

# %%
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt


import pandas as pd

mfcc_tsne_PCA_df = pd.read_csv('MFCCtsnePCA_Mean.csv')
mfcc_df = pd.read_csv('MFCC_Meaned_20.csv')
print(mfcc_tsne_PCA_df.head())

# Filter the rows where 'Song' equals specific values (1, 2, 3, 4, 5, 6)
song_identifiers = ['mfcc_output_16', 'mfcc_output_56', 'mfcc_output_59', 'mfcc_output_40', 'mfcc_output_73','mfcc_output_3']

filtered_points = mfcc_tsne_PCA_df[mfcc_tsne_PCA_df['Song'].isin(song_identifiers)]


song_names = mfcc_tsne_PCA_df['Song']  # Save the 'Song' column
mfcc_tsne_PCA_df = mfcc_tsne_PCA_df.drop(columns=['Song'])  # Use only the MFCC coefficients for PCA and t-SNE



# Display or assign these points as centroids
initial_centroids = filtered_points[['Dimension 1', 'Dimension 2']].values

print("Initial Centroids:")
print(initial_centroids)

mfcc_tsne_PCA_df = mfcc_tsne_PCA_df.drop(mfcc_tsne_PCA_df.columns[0], axis=1)
print(mfcc_tsne_PCA_df.head())

# Assuming mfcc_df is your DataFrame with 115 songs and 20 MFCC coefficients
gmm = GaussianMixture(n_components=6,means_init=initial_centroids, random_state=42)  # Use 6 components based on your categories
gmm_labels = gmm.fit_predict(mfcc_tsne_PCA_df)


gmm_probabilities = gmm.predict_proba(mfcc_tsne_PCA_df)
probability_df = pd.DataFrame(gmm_probabilities, columns=[f'Cluster_{i}' for i in range(6)])
probability_df['Song'] = song_names 
probability_df.to_csv('Mean_Probability.csv')

# Add GMM labels to the DataFrame for analysis
mfcc_df['GMM Cluster'] = gmm_labels

# Visualizing GMM clusters (you can use t-SNE/PCA results here too)
plt.figure(figsize=(8, 6))
plt.scatter(mfcc_tsne_PCA_df['Dimension 1'], mfcc_tsne_PCA_df['Dimension 2'], c=gmm_labels, cmap='viridis', edgecolor='k')
plt.title('GMM Clusters on t-SNE Reduced Data')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.colorbar(label='Cluster')
plt.show()

mfcc_tsne_PCA_df['GMM Cluster'] = gmm_labels

mfcc_tsne_PCA_df['Song'] = song_names  # Add the 'Song' column back to the t-SNE results
mfcc_tsne_PCA_df.to_csv('Output_GMM_Mean.csv')


# Optional: Print cluster assignment
print(mfcc_df['GMM Cluster'].value_counts())
# Out:
#    Unnamed: 0  Dimension 1  Dimension 2            Song
# 0           0     2.775616     2.081490  mfcc_output_49
# 1           1    -1.758819    -2.859134  mfcc_output_61
# 2           2    -1.013302    -1.872494  mfcc_output_75
# 3           3    -0.156048     2.630755  mfcc_output_74
# 4           4     5.043118     1.261157  mfcc_output_60
# Initial Centroids:
# [[ 0.91074306  2.8257613 ]
#  [ 4.804891    1.3159889 ]
#  [-1.3904114  -1.030895  ]
#  [ 3.5040085  -0.2330594 ]
#  [-0.75747764  1.6519263 ]
#  [ 2.6792727   0.88192123]]
#    Dimension 1  Dimension 2
# 0     2.775616     2.081490
# 1    -1.758819    -2.859134
# 2    -1.013302    -1.872494
# 3    -0.156048     2.630755
# 4     5.043118     1.261157
# GMM Cluster
# 5    43
# 2    23
# 4    21
# 0    20
# 1     4
# 3     4
# Name: count, dtype: int64
